# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings(action ='ignore')

# %%
df1= pd.read_csv('data/2019년 상반기 주유소 판매가격.csv', encoding = 'utf-8')  # 텍스트 불러올때  인코딩 맞춰 주면 좋다.

# %%
df2 = pd.read_csv('data/2019년 하반기 주유소 판매가격.csv',encoding = 'utf-8')
df2.head()
# Out:
#          번호      지역            상호              주소        기간     상표 셀프여부  \
# 0  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190701  SK에너지   셀프
# 1  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190702  SK에너지   셀프
# 2  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190703  SK에너지   셀프
# 3  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190704  SK에너지   셀프
# 4  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190705  SK에너지   셀프
#
#    고급휘발유   휘발유    경유  실내등유
# 0   1777  1577  1477     0
# 1   1777  1577  1477     0
# 2   1777  1577  1477     0
# 3   1777  1577  1477     0
# 4   1777  1577  1477     0

# %% [markdown]
# # 데이터 불러오기
# - 2019년 주유소들의 일자별 가격 데이터

# %%
# 상반기, 하반기 주유소 가격 데이터 조회
# 상반기
df1[df1.columns[7:]].head()
# Out:
#    고급휘발유   휘발유    경유  실내등유
# 0   1673  1465  1365     0
# 1   1673  1465  1365     0
# 2   1673  1465  1365     0
# 3   1673  1465  1365     0
# 4   1673  1465  1365     0

# %%
# 하반기
df2[df2.columns[7:]].head()
# Out:
#    고급휘발유   휘발유    경유  실내등유
# 0   1777  1577  1477     0
# 1   1777  1577  1477     0
# 2   1777  1577  1477     0
# 3   1777  1577  1477     0
# 4   1777  1577  1477     0

# %%
df2
# Out:
#              번호      지역             상호              주소        기간     상표 셀프여부  \
# 0      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190701  SK에너지   셀프
# 1      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190702  SK에너지   셀프
# 2      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190703  SK에너지   셀프
# 3      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190704  SK에너지   셀프
# 4      A0006039  서울 강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190705  SK에너지   셀프
# ...         ...     ...            ...             ...       ...    ...  ...
# 91119  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191227  GS칼텍스   셀프
# 91120  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191228  GS칼텍스   셀프
# 91121  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191229  GS칼텍스   셀프
# 91122  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191230  GS칼텍스   셀프
# 91123  A0032659  서울 중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191231  GS칼텍스   셀프
#
#        고급휘발유   휘발유    경유  실내등유
# ...

# %%
# 상반기, 하반기 DataFrame 합치기 판다스 
df=pd.concat([df1,df2],ignore_index =True)#, axis = 0)
df.shape
# Out:
# (181714, 11)

# %%
# DataFrame 기본 정보 조회
df.info()

#  nan 값없음.. , object,int type 만있음   , columns 11개
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181714 entries, 0 to 181713
# Data columns (total 11 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   번호      181714 non-null  object
#  1   지역      181714 non-null  object
#  2   상호      181714 non-null  object
#  3   주소      181714 non-null  object
#  4   기간      181714 non-null  int64
#  5   상표      181714 non-null  object
#  6   셀프여부    181714 non-null  object
#  7   고급휘발유   181714 non-null  int64
#  8   휘발유     181714 non-null  int64
#  9   경유      181714 non-null  int64
#  10  실내등유    181714 non-null  int64
# dtypes: int64(5), object(6)
# memory usage: 15.3+ MB

# %%
df.head()
# Out:
#          번호      지역            상호              주소        기간     상표 셀프여부  \
# 0  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190101  SK에너지   셀프
# 1  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190102  SK에너지   셀프
# 2  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190103  SK에너지   셀프
# 3  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190104  SK에너지   셀프
# 4  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190105  SK에너지   셀프
#
#    고급휘발유   휘발유    경유  실내등유
# 0   1673  1465  1365     0
# 1   1673  1465  1365     0
# 2   1673  1465  1365     0
# 3   1673  1465  1365     0
# 4   1673  1465  1365     0

# %%
df.describe()  #평균가격이 고급휘발유가 더 적고,표준 편차가 크다,max는 높음 //  min 값이  0 인것이 있어서 그런듯
                #.. 그래서 0이 왜 있는지 알아야 한다.
# Out:
#                  기간          고급휘발유            휘발유             경유  \
# count  1.817140e+05  181714.000000  181714.000000  181714.000000
# mean   2.019067e+07     763.284139    1567.148161    1435.564816
# std    3.453131e+02     937.368150     182.942737     171.892815
# min    2.019010e+07       0.000000       0.000000       0.000000
# 25%    2.019040e+07       0.000000    1459.000000    1333.000000
# 50%    2.019070e+07       0.000000    1529.000000    1389.000000
# 75%    2.019093e+07    1768.000000    1599.000000    1478.000000
# max    2.019123e+07    2699.000000    2356.000000    2196.000000
#
#                 실내등유
# count  181714.000000
# mean      454.800412
# std       572.002790
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%      1100.000000
# max      1640.000000

# %%
df.describe(include=object)#//'top'을 보면  셀프보다는 일반이 더많다.
# Out:
#               번호      지역      상호                      주소      상표    셀프여부
# count     181714  181714  181714                  181714  181714  181714
# unique       512      25     507                     512       8       2
# top     A0000690  서울 강남구   신성주유소  서울 영등포구 가마산로 367 (대림동)   SK에너지      일반
# freq         365   14597    1095                     365   71062  108492

# %%
# 상표 컬럼의 고유값 조회
df['상표'].unique()
# Out:
# array(['SK에너지', 'GS칼텍스', 'S-OIL', '현대오일뱅크', '알뜰주유소', 'NH-OIL', '알뜰(ex)',
#        '자가상표'], dtype=object)

# %%
df['상표'].value_counts()
# Out:
# SK에너지     71062
# GS칼텍스     49494
# 현대오일뱅크    28583
# S-OIL     27027
# 알뜰주유소      4021
# 자가상표        982
# 알뜰(ex)      365
# NH-OIL      180
# Name: 상표, dtype: int64

# %%
# 지역 컬럼의 고유값 조회
print(df['지역'].unique())
print(df['지역'].value_counts())
# Out:
# ['서울 강남구' '서울 강동구' '서울 강북구' '서울 강서구' '서울 관악구' '서울 광진구' '서울 구로구' '서울 금천구'
#  '서울 노원구' '서울 도봉구' '서울 동대문구' '서울 동작구' '서울 마포구' '서울 서대문구' '서울 서초구' '서울 성동구'
#  '서울 성북구' '서울 송파구' '서울 양천구' '서울 영등포구' '서울 용산구' '서울 은평구' '서울 종로구' '서울 중구'
#  '서울 중랑구']
# 서울 강남구     14597
# 서울 서초구     13762
# 서울 강서구     12572
# 서울 영등포구    11667
# 서울 송파구     11630
# 서울 양천구      9149
# 서울 성북구      8080
# 서울 동대문구     7996
# 서울 구로구      7917
# 서울 도봉구      6711
# 서울 광진구      6450
# 서울 은평구      6199
# 서울 성동구      6192
# 서울 관악구      5997
# 서울 강동구      5897
# 서울 중랑구      5719
# 서울 서대문구     5594
# 서울 노원구      5466
# 서울 용산구      5439
# 서울 금천구      4738
# 서울 강북구      4736
# 서울 중구       4235
# 서울 마포구      4051
# 서울 동작구      3644
# 서울 종로구      3276
# Name: 지역, dtype: int64

# %%
df['셀프여부'].value_counts()
# Out:
# 일반    108492
# 셀프     73222
# Name: 셀프여부, dtype: int64

# %% [markdown]
# > ### str accessor
# > - `Series.str.String메소드()`
# > - 문자열 타입 Series에 String 메소드들을 사용하여 일괄처리 할 수 있도록 한다.
# > - str accessor 메소드 : https://pandas.pydata.org/pandas-docs/stable/reference/series.html#api-series-str
#
# > ### datetime으로 변환
# > - `pd.to_datetime(변환할 Series)`
# > - x 또는 y 축이 날짜 일 경우 datetime 타입으로 처리하는 것이 좋다.
# > - datetime을 변환하면 날짜만의 기능을 다룰 수 있다.
# >     - dt accessor를 이용해 datetime의 속성값들을(년, 월, 일 등) 추출할 수 있다.
# >     - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.html

# %%
df.head(2)
# Out:
#          번호      지역            상호              주소        기간     상표 셀프여부  \
# 0  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190101  SK에너지   셀프
# 1  A0006039  서울 강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640  20190102  SK에너지   셀프
#
#    고급휘발유   휘발유    경유  실내등유
# 0   1673  1465  1365     0
# 1   1673  1465  1365     0

# %%
# 사진 강사님이 한 apply 사용한 방법 보기
# .str.split(' ').str[1] 도있음 

# 지역 컬럼의 값을 이용하여 "구" 컬럼 생성 (지역에서 구만 추출)
#df['구']=df['지역'].str.slice(start =3) #s.str.slice(start=1)
df.insert(2,'구',df['지역'].str.slice(start =3))

# %%
df.tail()
# Out:
#               번호      지역    구             상호              주소        기간     상표  \
# 181709  A0032659  서울 중랑구  중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191227  GS칼텍스
# 181710  A0032659  서울 중랑구  중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191228  GS칼텍스
# 181711  A0032659  서울 중랑구  중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191229  GS칼텍스
# 181712  A0032659  서울 중랑구  중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191230  GS칼텍스
# 181713  A0032659  서울 중랑구  중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475  20191231  GS칼텍스
#
#        셀프여부  고급휘발유   휘발유    경유  실내등유
# 181709   셀프      0  1540  1389  1100
# 181710   셀프      0  1540  1389  1100
# 181711   셀프      0  1540  1389  1100
# 181712   셀프      0  1540  1389  1100
# 181713   셀프      0  1540  1389  1100

# %%
df['기간']
# Out:
# 0         20190101
# 1         20190102
# 2         20190103
# 3         20190104
# 4         20190105
#             ...
# 181709    20191227
# 181710    20191228
# 181711    20191229
# 181712    20191230
# 181713    20191231
# Name: 기간, Length: 181714, dtype: int64

# %%
## time에 관한 설명~!
import time

a = time.time()  # 1970.01.01 00:00:00(유닉스 타임)  부터 실행시점까지 초단위로 계산한 값. 
## z코드 
b = time.time()

print(b-a) # 몇초 ( 걸린시간)
# Out:
# 0.0

# %%
# 강사님 파일 보면서 다시 써보기

# %%
# read_csv() 로 읽을때 변환. 
# parse_dates=['datetime 타입으로 읽을 컬럼', ...]
# date_parser=변환함수
from datetime import datetime
def parser(x):
    # strftime(): datetime->str (to_char())
    # strptime(): str -> datetime (to_date())
    # x: 컬럼의 원소들
    return datetime.strptime(x, '%Y%m%d')
first2 = pd.read_csv('data/2019년 상반기 주유소 판매가격.csv',
                     parse_dates=['기간'],
                     date_parser=lambda x: datetime.strptime(x, '%Y%m%d'))
#                      date_parser=parser)  #'기간' 컬럼의 값을 읽어올때 parser함수를 이용해 datetime 타입으로 변환해라.
first2.info()

# %%
# 기간 컬럼을 datetime 타입으로 변경
#pd.to_datetime(변환할 Series)
# 어디까지가 년도고 월이고 일인지 format 으로 알려줘야한다.
#20190101  %Y: 년도(4자리) , %m:월, %d:일, %H시간 , %M분, %S:초  ---> 나머지는 2자리 수 로 반환

df['기간']=pd.to_datetime(df['기간'],format = "%Y%m%d")  # 이렇게 포멧 잡아줘야한다.

# %%
df['기간']
# Out:
# 0        2019-01-01
# 1        2019-01-02
# 2        2019-01-03
# 3        2019-01-04
# 4        2019-01-05
#             ...
# 181709   2019-12-27
# 181710   2019-12-28
# 181711   2019-12-29
# 181712   2019-12-30
# 181713   2019-12-31
# Name: 기간, Length: 181714, dtype: datetime64[ns]

# %%
df.head(1)
# Out:
#          번호      지역    구            상호              주소         기간     상표 셀프여부  \
# 0  A0006039  서울 강남구  강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-01  SK에너지   셀프
#
#    고급휘발유   휘발유    경유  실내등유
# 0   1673  1465  1365     0

# %%
# 기간 컬럼을 이용해 "월", "일", "요일" 컬럼 생성//dayofweek(요일/ 0: 월요일)
df.insert(6,'월',df['기간'].dt.month)

# %%
df.insert(7,'일',df['기간'].dt.day)

# %%
df.insert(8,'요일',df['기간'].dt.dayofweek)

# %%
# 요일을 문자열로 변환하고 싶을때 ((요일/ 0: 월요일))

def change_month_str(x):
    if x ==0:
        return '월'
    elif x ==1:
        return '화'
    elif x ==2:
        return '수'
    elif x ==3:
        return '목'
    elif x ==4:
        return '금'
    elif x ==5:
        return '토'
    elif x ==6:
        return '일'

# %%
df['요일'].apply(change_month_str)   # 꼭기억하기
# Out:
# 0         화
# 1         수
# 2         목
# 3         금
# 4         토
#          ..
# 181709    금
# 181710    토
# 181711    일
# 181712    월
# 181713    화
# Name: 요일, Length: 181714, dtype: object

# %%
df['요일'] = df['요일'].apply(change_month_str)

# %%
df.head()
# Out:
#          번호      지역    구            상호              주소         기간  월  일 요일  \
# 0  A0006039  서울 강남구  강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-01  1  1  화
# 1  A0006039  서울 강남구  강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-02  1  2  수
# 2  A0006039  서울 강남구  강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-03  1  3  목
# 3  A0006039  서울 강남구  강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-04  1  4  금
# 4  A0006039  서울 강남구  강남구  (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-05  1  5  토
#
#       상표 셀프여부  고급휘발유   휘발유    경유  실내등유
# 0  SK에너지   셀프   1673  1465  1365     0
# 1  SK에너지   셀프   1673  1465  1365     0
# 2  SK에너지   셀프   1673  1465  1365     0
# 3  SK에너지   셀프   1673  1465  1365     0
# 4  SK에너지   셀프   1673  1465  1365     0

# %%
# 휘발유 가격이 가장 비싼 5개 행 조회
 df.sort_values('휘발유',ascending = False).head()  #---> 내가한것
# Out:
#               번호     지역   구     상호            주소         기간  월   일  요일     상표  \
# 176952  A0000767  서울 중구  중구  서남주유소  서울 중구 통일로 30 2019-05-12  5  12   6  SK에너지
# 86363   A0000767  서울 중구  중구  서남주유소  서울 중구 통일로 30 2019-05-13  5  13   0  SK에너지
# 176953  A0000767  서울 중구  중구  서남주유소  서울 중구 통일로 30 2019-05-13  5  13   0  SK에너지
# 176951  A0000767  서울 중구  중구  서남주유소  서울 중구 통일로 30 2019-05-11  5  11   5  SK에너지
# 176950  A0000767  서울 중구  중구  서남주유소  서울 중구 통일로 30 2019-05-10  5  10   4  SK에너지
#
#        셀프여부  고급휘발유   휘발유    경유  실내등유
# 176952   일반   2599  2257  2093     0
# 86363    일반   2599  2257  2093     0
# 176953   일반   2599  2257  2093     0
# 176951   일반   2599  2257  2093     0
# 176950   일반   2599  2257  2093     0

# %%
# 휘발유 가격이 가장 비싼 5개 행 조회 (강사님) // 가격이 똑같을때 월 로 정렬 
df.sort_values(['휘발유','월'],ascending = [False,True]).head()
# Out:
#               번호     지역   구     상호            주소         기간  월   일 요일     상표  \
# 177210  A0000767  서울 중구  중구  서남주유소  서울 중구 통일로 30 2019-09-24  9  24  화  SK에너지
# 177211  A0000767  서울 중구  중구  서남주유소  서울 중구 통일로 30 2019-09-25  9  25  수  SK에너지
# 177212  A0000767  서울 중구  중구  서남주유소  서울 중구 통일로 30 2019-09-26  9  26  목  SK에너지
# 177213  A0000767  서울 중구  중구  서남주유소  서울 중구 통일로 30 2019-09-27  9  27  금  SK에너지
# 177214  A0000767  서울 중구  중구  서남주유소  서울 중구 통일로 30 2019-09-28  9  28  토  SK에너지
#
#        셀프여부  고급휘발유   휘발유    경유  실내등유
# 177210   일반   2649  2356  2196     0
# 177211   일반   2649  2356  2196     0
# 177212   일반   2699  2356  2196     0
# 177213   일반   2699  2356  2196     0
# 177214   일반   2699  2356  2196     0

# %%
df.groupby('휘발유').filter(lambda x : x['휘발유'].max()>=2257) # filter 쓰는 문제는 아님.. fliter는 bool값을 넣어야지 그냥 max()까지만하면안됨
# Out:
#               번호     지역   구     상호            주소         기간  월   일  요일     상표  \
# 86357   A0000767  서울 중구  중구  서남주유소  서울 중구 통일로 30 2019-05-07  5   7   1  SK에너지
# 86358   A0000767  서울 중구  중구  서남주유소  서울 중구 통일로 30 2019-05-08  5   8   2  SK에너지
# 86359   A0000767  서울 중구  중구  서남주유소  서울 중구 통일로 30 2019-05-09  5   9   3  SK에너지
# 86360   A0000767  서울 중구  중구  서남주유소  서울 중구 통일로 30 2019-05-10  5  10   4  SK에너지
# 86361   A0000767  서울 중구  중구  서남주유소  서울 중구 통일로 30 2019-05-11  5  11   5  SK에너지
# 86362   A0000767  서울 중구  중구  서남주유소  서울 중구 통일로 30 2019-05-12  5  12   6  SK에너지
# 86363   A0000767  서울 중구  중구  서남주유소  서울 중구 통일로 30 2019-05-13  5  13   0  SK에너지
# 86364   A0000767  서울 중구  중구  서남주유소  서울 중구 통일로 30 2019-05-14  5  14   1  SK에너지
# 176947  A0000767  서울 중구  중구  서남주유소  서울 중구 통일로 30 2019-05-07  5   7   1  SK에너지
# 176948  A0000767  서울 중구  중구  서남주유소  서울 중구 통일로 30 2019-05-08  5   8   2  SK에너지
# 176949  A0000767  서울 중구  중구  서남주유소  서울 중구 통일로 30 2019-05-09  5   9   3  SK에너지
# ...

# %%
# 휘발유 가격이 가장 저렴한 5개 행 조회 (단 0원인 주유소 제외)
# 상위, 하위 N개 조회 => 정렬후(오름,내림차순) head()
df[df['휘발유']!=0].sort_values('휘발유').head()
# Out:
#              번호      지역    구                   상호                    주소  \
# 13148  A0033328  서울 강서구  강서구  KH에너지(주)직영 KH외발산주유소        서울 강서구 방화대로 30
# 82475  A0000605  서울 은평구  은평구                삼융주유소  서울 은평구 수색로 299 (수색동)
# 82474  A0000605  서울 은평구  은평구                삼융주유소  서울 은평구 수색로 299 (수색동)
# 82476  A0000605  서울 은평구  은평구                삼융주유소  서울 은평구 수색로 299 (수색동)
# 82998  A0000690  서울 은평구  은평구    지에스칼텍스(주)수색뉴타운주유소  서울 은평구 수색로 350 (수색동)
#
#               기간  월   일 요일     상표 셀프여부  고급휘발유   휘발유    경유  실내등유
# 13148 2019-02-07  2   7  목  SK에너지   셀프   1788  1255  1155     0
# 82475 2019-01-31  1  31  목  SK에너지   일반      0  1260  1160     0
# 82474 2019-01-30  1  30  수  SK에너지   일반      0  1260  1160     0
# 82476 2019-02-01  2   1  금  SK에너지   일반      0  1260  1160     0
# 82998 2019-01-26  1  26  토  GS칼텍스   셀프      0  1265  1165     0

# %%
# 고급휘발유 가격이 가장 비싼 5개 행 조회
df.sort_values('고급휘발유',ascending = False).head()
# Out:
#               번호     지역   구     상호            주소         기간   월   일 요일     상표  \
# 177217  A0000767  서울 중구  중구  서남주유소  서울 중구 통일로 30 2019-10-01  10   1  화  SK에너지
# 177212  A0000767  서울 중구  중구  서남주유소  서울 중구 통일로 30 2019-09-26   9  26  목  SK에너지
# 177213  A0000767  서울 중구  중구  서남주유소  서울 중구 통일로 30 2019-09-27   9  27  금  SK에너지
# 177214  A0000767  서울 중구  중구  서남주유소  서울 중구 통일로 30 2019-09-28   9  28  토  SK에너지
# 177215  A0000767  서울 중구  중구  서남주유소  서울 중구 통일로 30 2019-09-29   9  29  일  SK에너지
#
#        셀프여부  고급휘발유   휘발유    경유  실내등유
# 177217   일반   2699  2356  2196     0
# 177212   일반   2699  2356  2196     0
# 177213   일반   2699  2356  2196     0
# 177214   일반   2699  2356  2196     0
# 177215   일반   2699  2356  2196     0

# %%
# 고급휘발유 가격이 가장 저렴한 5개 행 조회 (단 0원인 주유소 제외)
df[df['고급휘발유']!=0].sort_values('고급휘발유').head()  # iloc 은 블리언 인덱싱 지원 안함
# Out:
#              번호      지역    구       상호                       주소         기간  월  \
# 17460  A0000520  서울 강서구  강서구  하이웨이주유소  서울특별시 강서구 공항대로 432(화곡동) 2019-01-15  1
# 17459  A0000520  서울 강서구  강서구  하이웨이주유소  서울특별시 강서구 공항대로 432(화곡동) 2019-01-14  1
# 17458  A0000520  서울 강서구  강서구  하이웨이주유소  서울특별시 강서구 공항대로 432(화곡동) 2019-01-13  1
# 17457  A0000520  서울 강서구  강서구  하이웨이주유소  서울특별시 강서구 공항대로 432(화곡동) 2019-01-12  1
# 17456  A0000520  서울 강서구  강서구  하이웨이주유소  서울특별시 강서구 공항대로 432(화곡동) 2019-01-11  1
#
#         일 요일     상표 셀프여부  고급휘발유   휘발유    경유  실내등유
# 17460  15  화  S-OIL   셀프   1397  1275  1175     0
# 17459  14  월  S-OIL   셀프   1397  1275  1175     0
# 17458  13  일  S-OIL   셀프   1397  1275  1175     0
# 17457  12  토  S-OIL   셀프   1397  1275  1175     0
# 17456  11  금  S-OIL   셀프   1397  1275  1175     0

# %%
# 경유 가격이 가장 비싼 5개 행 조회
df.sort_values('경유',ascending = False).head()
# Out:
#               번호     지역   구     상호            주소         기간   월   일 요일     상표  \
# 177211  A0000767  서울 중구  중구  서남주유소  서울 중구 통일로 30 2019-09-25   9  25  수  SK에너지
# 177212  A0000767  서울 중구  중구  서남주유소  서울 중구 통일로 30 2019-09-26   9  26  목  SK에너지
# 177217  A0000767  서울 중구  중구  서남주유소  서울 중구 통일로 30 2019-10-01  10   1  화  SK에너지
# 177216  A0000767  서울 중구  중구  서남주유소  서울 중구 통일로 30 2019-09-30   9  30  월  SK에너지
# 177215  A0000767  서울 중구  중구  서남주유소  서울 중구 통일로 30 2019-09-29   9  29  일  SK에너지
#
#        셀프여부  고급휘발유   휘발유    경유  실내등유
# 177211   일반   2649  2356  2196     0
# 177212   일반   2699  2356  2196     0
# 177217   일반   2699  2356  2196     0
# 177216   일반   2699  2356  2196     0
# 177215   일반   2699  2356  2196     0

# %%
# 경유 가격이 가장 저렴한 5개 행 조회 (단 0원인 주유소 제외)
df[df['경유']!=0].sort_values('경유').head()
# Out:
#              번호      지역    구                   상호                    주소  \
# 13148  A0033328  서울 강서구  강서구  KH에너지(주)직영 KH외발산주유소        서울 강서구 방화대로 30
# 50707  A0011826  서울 서초구  서초구             만남의광장주유소  서울 서초구 양재대로12길 73-71
# 82476  A0000605  서울 은평구  은평구                삼융주유소  서울 은평구 수색로 299 (수색동)
# 82475  A0000605  서울 은평구  은평구                삼융주유소  서울 은평구 수색로 299 (수색동)
# 82474  A0000605  서울 은평구  은평구                삼융주유소  서울 은평구 수색로 299 (수색동)
#
#               기간  월   일 요일      상표 셀프여부  고급휘발유   휘발유    경유  실내등유
# 13148 2019-02-07  2   7  목   SK에너지   셀프   1788  1255  1155     0
# 50707 2019-01-13  1  13  일  알뜰(ex)   셀프      0  1297  1157     0
# 82476 2019-02-01  2   1  금   SK에너지   일반      0  1260  1160     0
# 82475 2019-01-31  1  31  목   SK에너지   일반      0  1260  1160     0
# 82474 2019-01-30  1  30  수   SK에너지   일반      0  1260  1160     0

# %%
# 상표별 휘발유 평균가격 조회
#df.groupby('상표')['휘발유'].mean()
#  df.loc[df['휘발유']!=0, '휘발유'].mean() # 0을 제외한 전체 평균
상표_mean=df.loc[df['휘발유']!=0].groupby('상표')['휘발유'].mean()
상표_mean
# Out:
# 상표
# GS칼텍스     1564.313469
# NH-OIL    1449.088889
# S-OIL     1532.472987
# SK에너지     1612.782625
# 알뜰(ex)    1431.347945
# 알뜰주유소     1447.875902
# 자가상표      1492.085540
# 현대오일뱅크    1515.670352
# Name: 휘발유, dtype: float64

# %%
# 상표별 휘발유 평균가격 시각화
# a= df.groupby('상표')['휘발유'].mean()  ---> 내가한것
# plt.figure(figsize =(8,8))
# plt.bar(a.index,a)
# plt.xticks(rotation = 30)

# plt.show()
상표_mean.plot.bar(rot =30, figsize =(10,6), label ='휘발유가격')

# 텍스트로 각 막ㄷ대에 값을 출력

for i in range(상표_mean.size):
    plt.text(i-0.2,         # x축 좌표
             상표_mean[i],  #y 축 죄표
             np.round(상표_mean[i],1), # 출력할 text
             fontsize = 12)
    
plt.axhline(y= 1500, color ='r', linestyle ='--', label = '1500원 기준선')

plt.legend(bbox_to_anchor=(1,1), loc = 'lower left')

    


plt.show()

# %%
import seaborn as sns

# %%
# 셀프주유소와 일반주유소 개수 확인
df['셀프여부'].value_counts()#normalize = True)  --> 비율
# Out:
# 일반    108492
# 셀프     73222
# Name: 셀프여부, dtype: int64

# %%
df.tail()
# Out:
#               번호      지역    구             상호              주소         기간   월  \
# 181709  A0032659  서울 중랑구  중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-27  12
# 181710  A0032659  서울 중랑구  중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-28  12
# 181711  A0032659  서울 중랑구  중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-29  12
# 181712  A0032659  서울 중랑구  중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-30  12
# 181713  A0032659  서울 중랑구  중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-31  12
#
#          일  요일     상표 셀프여부  고급휘발유   휘발유    경유  실내등유
# 181709  27   4  GS칼텍스   셀프      0  1540  1389  1100
# 181710  28   5  GS칼텍스   셀프      0  1540  1389  1100
# 181711  29   6  GS칼텍스   셀프      0  1540  1389  1100
# 181712  30   0  GS칼텍스   셀프      0  1540  1389  1100
# 181713  31   1  GS칼텍스   셀프      0  1540  1389  1100

# %%
# 셀프주유소와 일반주유소 개수 시각화
#sns.countplot(df['셀프여부'])
df['셀프여부'].value_counts().plot(kind = 'bar')
plt.show()

# %%
# 셀프 여부에 따른 휘발유 평균 가격 비교 (0원 제외)
x = df[df['휘발유']!=0].groupby('셀프여부')['휘발유'].mean()
x
# Out:
# 셀프여부
# 셀프    1490.262029
# 일반    1619.690059
# Name: 휘발유, dtype: float64

# %%
plt.bar(x.index,x,color =['r','b'])
plt.show()

# %%
# 상표별 일반/셀프 주유소의 휘발유 가격 평균 비교  
df[df['휘발유']!=0].groupby(['셀프여부','상표'])['휘발유'].mean() # 시리즈 형태
# Out:
# 셀프여부  상표
# 셀프    GS칼텍스     1481.410074
#       S-OIL     1481.437428
#       SK에너지     1505.054771
#       알뜰(ex)    1431.347945
#       알뜰주유소     1434.726027
#       자가상표      1494.409449
#       현대오일뱅크    1483.686804
# 일반    GS칼텍스     1610.516144
#       NH-OIL    1449.088889
#       S-OIL     1579.789061
#       SK에너지     1691.365496
#       알뜰주유소     1455.372511
#       자가상표      1491.740351
#       현대오일뱅크    1534.510147
# Name: 휘발유, dtype: float64

# %%
# 상표별 일반/셀프 주유소의 휘발유 가격 평균 비교  // df[df['휘발유']!=0] 인 데이터 프레임에서 
a =df[df['휘발유']!=0].pivot_table(index = '상표' , columns ='셀프여부', values ='휘발유', aggfunc = 'mean')
a.head(2)
a
# Out:
# 셀프여부             셀프           일반
# 상표
# GS칼텍스   1481.410074  1610.516144
# NH-OIL          NaN  1449.088889
# S-OIL   1481.437428  1579.789061
# SK에너지   1505.054771  1691.365496
# 알뜰(ex)  1431.347945          NaN
# 알뜰주유소   1434.726027  1455.372511
# 자가상표    1494.409449  1491.740351
# 현대오일뱅크  1483.686804  1534.510147

# %%
a.plot.bar(figsize=(7,7))
plt.xticks(rotation =45)

plt.show()

# %%
# 상표별 일반/셀프 주유소의 휘발유 가격 평균 비교 시각화
df.pivot_table(index = '상표' , columns ='셀프여부', values ='휘발유', aggfunc = 'mean').plot(kind ='bar', figsize = (7,7), cmap ='rainbow')
plt.title('상표별 일반/셀프 주유소의 휘발유 가격 평균 비교')


#for idx, txt in enumerate()  해보기
#plt.text(0,1600,'ㅇㅇ')
plt.legend(bbox_to_anchor=(1,1),loc='upper left')
plt.xticks(rotation =45)
plt.show()

# %%
# 상표별 일반/셀프 주유소의 휘발유 가격에 대한 분포 확인 - boxplot으로 시각화
plt.figure(figsize=(15,10))

sns.boxplot(y= '휘발유', x= '상표', hue ='셀프여부', data = df[df['휘발유']!=0]) 
plt.xticks(rotation =45)
plt.show()

# %%
df[df['휘발유']!=0]  # 휘발유 가격이 0 인데이터를 제외한 데이터 프레임!!! 이걸 이용했어야한다~~!!!
# Out:
#               번호      지역    구             상호              주소         기간   월  \
# 0       A0006039  서울 강남구  강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-01   1
# 1       A0006039  서울 강남구  강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-02   1
# 2       A0006039  서울 강남구  강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-03   1
# 3       A0006039  서울 강남구  강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-04   1
# 4       A0006039  서울 강남구  강남구   (주)동하힐탑셀프주유소  서울 강남구 논현로 640 2019-01-05   1
# ...          ...     ...  ...            ...             ...        ...  ..
# 181709  A0032659  서울 중랑구  중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-27  12
# 181710  A0032659  서울 중랑구  중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-28  12
# 181711  A0032659  서울 중랑구  중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-29  12
# 181712  A0032659  서울 중랑구  중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-30  12
# 181713  A0032659  서울 중랑구  중랑구  지에스칼텍스㈜ 소망주유소  서울 중랑구 망우로 475 2019-12-31  12
#
#          일 요일     상표 셀프여부  고급휘발유   휘발유    경유  실내등유
# ...

# %%
# 상표별 휘발유 가격의 분포를 boxplot으로 시각화
plt.figure(figsize=(10,7))
#sns.boxplot(y= '휘발유', x= '상표', data = df) 
sns.boxplot(y= '휘발유', x= '상표', data = df[df['휘발유']!=0]) 

plt.xticks(rotation = 30)
plt.show()

# %%
# 상표별 휘발유 가격의 분포를 셀프여부로 나눠 boxplot으로 시각화
plt.figure(figsize =(15,10))
sns.boxplot(x='상표', y='휘발유', hue ='셀프여부',data= df[df['휘발유']>0])


plt.xticks(rotation=30)
plt.show()

# %%
# 구별 휘발유 가격의 평균
k=df[df['휘발유']>0].groupby('구')['휘발유'].mean().sort_values()
k
# Out:
# 구
# 강북구     1454.131601
# 중랑구     1469.009092
# 금천구     1477.121992
# 은평구     1481.964026
# 강서구     1489.173443
# 광진구     1490.597054
# 도봉구     1494.393741
# 동대문구    1507.399099
# 성북구     1508.321614
# 양천구     1513.055641
# 동작구     1513.717111
# 관악구     1518.635029
# 송파구     1518.957954
# 구로구     1525.410383
# 서대문구    1528.943332
# 노원구     1531.221551
# 영등포구    1568.279506
# 강동구     1577.487784
# 서초구     1577.704514
# 성동구     1583.659561
# 마포구     1690.590269
# 강남구     1713.328332
# 종로구     1838.554945
# 용산구     1887.254609
# 중구      1976.948052
# Name: 휘발유, dtype: float64

# %%
# 구별 휘발유 가격의 평균 시각화/// seaborn 으론 안됨!
plt.figure(figsize =(15,8))

plt.xticks(rotation=45)
plt.bar(k.index,k)

plt.show()

# %%
구별휘발유평균=df[df['휘발유']>0].groupby('구')['휘발유'].mean()

# %%
# 구별 휘발유 가격의 평균 시각화
k.plot(kind = 'bar', figsize =(15,7), rot = 40)


#평균가격을 기준선
plt.axhline(y= 구별휘발유평균.mean(), color ='r', label ='휘발유 평균 기준선')
plt.legend()

plt.show()

# %%
df[df['구'] == '중구'].groupby('상표')['휘발유'].mean()
# Out:
# 상표
# GS칼텍스     2091.866438
# S-OIL     1783.369863
# SK에너지     2060.617512
# 알뜰주유소     1601.552743
# 자가상표      1418.859375
# 현대오일뱅크    1711.669903
# Name: 휘발유, dtype: float64

# %%
# 중구(평균이 가장높음)의 상표별 휘발유 평균가격
df[df['구'] == '중구'].groupby('상표')['휘발유',].mean()
#df[df['구'] == '중구'].groupby('상표')[['휘발유','경유',]].mean()

# k =df.pivot_table(index = '구', columns = '상호', values = '휘발유', aggfunc = 'mean')  ==> 내가 했던거 틀림
# k.loc['중구']
# Out:
#                 휘발유
# 상표
# GS칼텍스   2091.866438
# S-OIL   1783.369863
# SK에너지   2060.617512
# 알뜰주유소   1601.552743
# 자가상표    1418.859375
# 현대오일뱅크  1711.669903

# %%
# 월 평균 휘발유 가격의 평균
월_평균_휘발유=df.groupby('월')['휘발유'].mean()#// 0빼려면 df 대신  0 없는 데이터 프레임 넣는다.
월_평균_휘발유
# Out:
# 월
# 1     1466.554672
# 2     1446.624956
# 3     1465.159889
# 4     1519.481056
# 5     1606.096255
# 6     1605.343367
# 7     1585.726529
# 8     1589.339464
# 9     1633.125891
# 10    1634.464547
# 11    1620.687606
# 12    1630.535819
# Name: 휘발유, dtype: float64

# %%
month
# Out:
# 월
# 1     1466.554672
# 2     1446.624956
# 3     1465.159889
# 4     1519.481056
# 5     1606.096255
# 6     1605.343367
# 7     1585.726529
# 8     1589.339464
# 9     1633.125891
# 10    1634.464547
# 11    1620.687606
# 12    1630.535819
# Name: 휘발유, dtype: float64

# %%
[f'{m}월' for m in range(1,13)]
# Out:
# ['1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월', '10월', '11월', '12월']

# %%
# 월별 휘발유 가격 변화 추세 시각화
#sns.lineplot(x = df.index ,y = "A", data = df
월_평균_휘발유.plot(kind = 'line',figsize =(20,7))

plt.xticks(ticks = range(1,13), labels = [f'{m}월' for m in range(1,13)]) # tick 위치, label(생략 - tick 의 위치가 label)

plt.show()

# %%
# 각 구의 월별 평균 휘발유 가격 
구_월별_휘발유_평균=df.pivot_table(index= '월', columns = '구', values ='휘발유', aggfunc ='mean')

# %%
# 각 구의 월별 평균가격의 변화추이 시각화

#df.pivot_table(index= '월', columns = '구', values ='휘발유', aggfunc ='mean')
구_월별_휘발유_평균.plot.line(figsize =(20,7))

#plt.legend(loc= 'lower left',bbox_to_anchor(1,0.5))
plt.xticks(ticks = range(1,13),labels = [f'{m}월' for m in range(1,13)])

plt.legend(loc='center left', 
           bbox_to_anchor=(1, 0.5),
           ncol=2)

plt.show()

# %%
# 가장 휘발유가격이 비싼 주유소 상위 5 
df[df['휘발유']!=0].groupby('상호')['휘발유'].max().sort_values(ascending=False).head()  #내가한거
# Out:
# 상호
# 서남주유소          2356
# SC(주) 역전주유소    2278
# 필동주유소          2259
# 장충주유소          2250
# 뉴서울(강남)        2218
# Name: 휘발유, dtype: int64

# %%
# 가장 휘발유가격이 비싼 주유소 상위 5  - 수업시간
# 각주유소별 평균 => 정렬
비싼주유소 = df.groupby('상호')['휘발유'].mean().sort_values(ascending = False).head()
비싼주유소
# Out:
# 상호
# 서남주유소          2207.252055
# 장충주유소          2139.323288
# 뉴서울(강남)        2130.060274
# SC(주) 역전주유소    2125.778082
# 필동주유소          2098.095890
# Name: 휘발유, dtype: float64

# %%
# 가장 휘발유가격이 저렴한 주유소 상위 5 
df1=df[df['휘발유']>0]
#df1.groupby('상호')['휘발유'].min().sort_values().head()
저렴한주유소 =df1.groupby('상호')['휘발유'].mean().sort_values().head()
df1.groupby('상호')['휘발유'].mean().sort_values().head()
# Out:
# 상호
# (주)창원현대주유소           1362.553719
# SK네트웍스(주) 서울셀프주유소    1407.505051
# KH에너지(주)직영 수명산주유소    1416.021739
# 이케이에너지㈜ 강산주유소        1416.290909
# 북서울고속주유소             1419.131507
# Name: 휘발유, dtype: float64

# %%
# 휘발유 비싼 주유소의 상위 5개의 상호, 지역, 주소 조회(중복제거-drop_duplicates())  -- 내가한거 
df_drop=df['휘발유'].drop_duplicates()
df_up=df_drop.sort_values(ascending = False).head() #--- 틀림
df_up
# Out:
# 177210    2356
# 177280    2332
# 177308    2331
# 177294    2327
# 177266    2325
# Name: 휘발유, dtype: int64

# %%
df_up1=df.iloc[df_up.index]
df_up1[['상호', '지역', '주소']] #틀ㄹ림
# Out:
#            상호     지역            주소
# 177210  서남주유소  서울 중구  서울 중구 통일로 30
# 177280  서남주유소  서울 중구  서울 중구 통일로 30
# 177308  서남주유소  서울 중구  서울 중구 통일로 30
# 177294  서남주유소  서울 중구  서울 중구 통일로 30
# 177266  서남주유소  서울 중구  서울 중구 통일로 30

# %%
# 휘발유 비싼 주유소의 상위 5개의 상호, 지역, 주소 조회(중복제거-drop_duplicates()) - 수업시간

# %%
df.loc[df['상호'].isin(비싼주유소.index), ['상호','지역','주소']].drop_duplicates()
# Out:
#                 상호      지역                      주소
# 2896       뉴서울(강남)  서울 강남구    서울 강남구 언주로 716 (논현동)
# 85869  SC(주) 역전주유소   서울 중구            서울 중구 퇴계로 15
# 86231        서남주유소   서울 중구            서울 중구 통일로 30
# 86955        장충주유소   서울 중구  서울 중구 장충단로 202 (장충동1가)
# 87317        필동주유소   서울 중구   서울 중구  퇴계로 196 (필동2가)

# %%
# 휘발유 저렴한 주유소의 상위 5개의 상호, 지역, 주소 조회(중복제거)----> 같은가격중복 제거?
df.loc[df['상호'].isin(저렴한주유소.index),['상호','지역','주소']].drop_duplicates()
# Out:
#                       상호       지역                       주소
# 11120           북서울고속주유소   서울 강북구     서울 강북구 삼양로 410 (수유동)
# 13472  KH에너지(주)직영 수명산주유소   서울 강서구  서울 강서구 남부순환로 195 (내발산동)
# 19607  SK네트웍스(주) 서울셀프주유소   서울 관악구     서울 관악구 신림로 183 (신림동)
# 46052         (주)창원현대주유소  서울 서대문구          서울 서대문구 통일로 537
# 61061      이케이에너지㈜ 강산주유소   서울 성북구    서울 성북구 보문로 27 (보문동7가)
