# %%
import pandas as pd
import numpy as np

state_fruit = pd.read_csv('data/state_fruit.csv', index_col =0)
state_fruit  # 컬럼에 있는 값 ex) 12 가 어떤 의미 인지를 알 수 가 없다. 가격인지? 아님 생산량인지?
             # 12 가 apple은 아니니까// 주, 과일, 개수 를 컬럼으로 만들어서 가는게 처음에는 더 정리된 데이터이다.// 로우데이터..
            # 지금 이테이블은 편하게 보기 위해서 변경한 느낌
# Out:
#          Apple  Orange  Banana
# Texas       12      10      40
# Arizona      9       7      12
# Florida      0      14     190

# %%
s1 = state_fruit.stack()
s1
# Out:
# Texas    Apple      12
#          Orange     10
#          Banana     40
# Arizona  Apple       9
#          Orange      7
#          Banana     12
# Florida  Apple       0
#          Orange     14
#          Banana    190
# dtype: int64

# %%
s1.to_frame(name = "Count")
# Out:
#                 Count
# Texas   Apple      12
#         Orange     10
#         Banana     40
# Arizona Apple       9
#         Orange      7
#         Banana     12
# Florida Apple       0
#         Orange     14
#         Banana    190

# %%
s1=state_fruit.stack()

# %%
s2 = s1.reset_index()
s2
# Out:
#    level_0 level_1    0
# 0    Texas   Apple   12
# 1    Texas  Orange   10
# 2    Texas  Banana   40
# 3  Arizona   Apple    9
# 4  Arizona  Orange    7
# 5  Arizona  Banana   12
# 6  Florida   Apple    0
# 7  Florida  Orange   14
# 8  Florida  Banana  190

# %%
s2.columns=['state','fruits','count']
s2
# Out:
#      state  fruits  count
# 0    Texas   Apple     12
# 1    Texas  Orange     10
# 2    Texas  Banana     40
# 3  Arizona   Apple      9
# 4  Arizona  Orange      7
# 5  Arizona  Banana     12
# 6  Florida   Apple      0
# 7  Florida  Orange     14
# 8  Florida  Banana    190

# %%
s1
# Out:
# Texas    Apple      12
#          Orange     10
#          Banana     40
# Arizona  Apple       9
#          Orange      7
#          Banana     12
# Florida  Apple       0
#          Orange     14
#          Banana    190
# dtype: int64

# %%
s3=s1.rename_axis(['state','fruit'])
s3.reset_index(name='count')
# Out:
#      state   fruit  count
# 0    Texas   Apple     12
# 1    Texas  Orange     10
# 2    Texas  Banana     40
# 3  Arizona   Apple      9
# 4  Arizona  Orange      7
# 5  Arizona  Banana     12
# 6  Florida   Apple      0
# 7  Florida  Orange     14
# 8  Florida  Banana    190

# %%
s4=state_fruit.stack().rename_axis(['state','fruit']).reset_index(name='count')
s4
# Out:
#      state   fruit  count
# 0    Texas   Apple     12
# 1    Texas  Orange     10
# 2    Texas  Banana     40
# 3  Arizona   Apple      9
# 4  Arizona  Orange      7
# 5  Arizona  Banana     12
# 6  Florida   Apple      0
# 7  Florida  Orange     14
# 8  Florida  Banana    190

# %%
s=s4.set_index(keys=['state','fruit'])

# %%
s
# Out:
#                 count
# state   fruit
# Texas   Apple      12
#         Orange     10
#         Banana     40
# Arizona Apple       9
#         Orange      7
#         Banana     12
# Florida Apple       0
#         Orange     14
#         Banana    190

# %%
s.unstack()
# Out:
#         count
# fruit   Apple Banana Orange
# state
# Arizona     9     12      7
# Florida     0    190     14
# Texas      12     40     10

# %%
s1=s.unstack(level=0)
s1
# Out:
#          count
# state  Arizona Florida Texas
# fruit
# Apple        9       0    12
# Banana      12     190    40
# Orange       7      14    10

# %%
s1.droplevel(level=0,axis=1)
# Out:
# state   Arizona  Florida  Texas
# fruit
# Apple         9        0     12
# Banana       12      190     40
# Orange        7       14     10

# %%
state_fruit = pd.read_csv('data/state_fruit.csv')
state_fruit
# Out:
#   Unnamed: 0  Apple  Orange  Banana
# 0      Texas     12      10      40
# 1    Arizona      9       7      12
# 2    Florida      0      14     190

# %%
state_fruit = pd.read_csv('data/state_fruit.csv')
state_fruit=state_fruit.rename({state_fruit.columns[0]:'State'}, axis =1)
state_fruit
# Out:
#      State  Apple  Orange  Banana
# 0    Texas     12      10      40
# 1  Arizona      9       7      12
# 2  Florida      0      14     190

# %%
s=state_fruit.stack()
s.to_frame()
# Out:
#                 0
# 0 State     Texas
#   Apple        12
#   Orange       10
#   Banana       40
# 1 State   Arizona
#   Apple         9
#   Orange        7
#   Banana       12
# 2 State   Florida
#   Apple         0
#   Orange       14
#   Banana      190

# %%
state_fruit
# Out:
#      State  Apple  Orange  Banana
# 0    Texas     12      10      40
# 1  Arizona      9       7      12
# 2  Florida      0      14     190

# %%
state_fruit.melt(id_vars=['State'], value_vars=['Apple','Banana','Orange'], var_name='Fruit', value_name='Count')
# Out:
#      State   Fruit  Count
# 0    Texas   Apple     12
# 1  Arizona   Apple      9
# 2  Florida   Apple      0
# 3    Texas  Banana     40
# 4  Arizona  Banana     12
# 5  Florida  Banana    190
# 6    Texas  Orange     10
# 7  Arizona  Orange      7
# 8  Florida  Orange     14

# %%
s1= state_fruit.melt(id_vars=['State'], var_name='Fruit',value_name='cournt')

# %%
s1.set_index(keys=['State'])
# Out:
#           Fruit  cournt
# State
# Texas     Apple      12
# Arizona   Apple       9
# Florida   Apple       0
# Texas    Orange      10
# Arizona  Orange       7
# Florida  Orange      14
# Texas    Banana      40
# Arizona  Banana      12
# Florida  Banana     190

# %%
dic ={
    'A':[1,2,3,],
    'B':[10,20,30],
    'C': [100,200,300],
    'D': [1000,2000,3000],
    'E': ['가','나','다']
}
df = pd.DataFrame(dic)
df
# Out:
#    A   B    C     D  E
# 0  1  10  100  1000  가
# 1  2  20  200  2000  나
# 2  3  30  300  3000  다

# %%
df.pivot(index='A',columns='D',values="E")
# Out:
# D 1000 2000 3000
# A
# 1    가  NaN  NaN
# 2  NaN    나  NaN
# 3  NaN  NaN    다

# %%
import cx_Oracle

# %%
conn = cx_Oracle.connect('c##scott_join/tiger@localhost:1521/XE')
conn
# Out:
# <cx_Oracle.Connection to c##scott_join@localhost:1521/XE>

# %%
emp_df = pd.read_sql('select* from emp', con= conn, index_col='EMP_ID')
emp_df
# Out:
#          EMP_NAME      JOB_ID  MGR_ID  HIRE_DATE   SALARY  COMM_PCT  DEPT_ID
# EMP_ID
# 1509         g홍길동  FI_ACCOUNT     NaN 2021-02-15  60000.0       0.2    100.0
# 3220          박명수  FI_ACCOUNT     NaN 2020-08-15  10000.0       NaN      NaN
# 2020         이순신2  FI_ACCOUNT     NaN 2021-02-15   1999.0       NaN    110.0
# 103     Alexander     IT_PROG     NaN 2006-01-03  27000.0       NaN     60.0
# 104         Bruce     IT_PROG   103.0 2007-05-21  18000.0       NaN     60.0
# ...           ...         ...     ...        ...      ...       ...      ...
# 593           dan     IT_PROG     NaN 2011-02-23   2384.0       NaN      NaN
# 793           dan     IT_PROG     NaN 2011-02-23   2384.0       NaN      NaN
# 893           dan     IT_PROG     NaN 2011-02-23   2384.0       NaN      NaN
# 993           dan     IT_PROG     NaN 2011-02-23   2384.0       NaN      NaN
# 2000          이순신  FI_ACCOUNT     NaN 2021-02-15   1999.0       NaN    110.0
#
# [110 rows x 7 columns]

# %%
#cursor.close()
conn.close()

# %%
emp_df = pd.read_sql('select* from emp', con= conn, index_col='EMP_ID')
emp_df
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# <ipython-input-97-a9f0d59c5ff3> in <module>
# ----> 1 emp_df = pd.read_sql('select* from emp', con= conn, index_col='EMP_ID')
#       2 emp_df
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     481
#     482     if isinstance(pandas_sql, SQLiteDatabase):
# --> 483         return pandas_sql.read_query(
#     484             sql,
#     485             index_col=index_col,
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1725
#    1726         args = _convert_params(sql, params)
# -> 1727         cursor = self.execute(*args)
#    1728         columns = [col_desc[0] for col_desc in cursor.description]
#    1729
#
# ...
