# %% [markdown]
# ## 정렬
# ### index명/컬럼명을 순 정렬
# ---- 이름을 갖고
# - #### sort_index(axis, ascending=True)
#     - axis
#         - index명 기준 정렬(행) : 'index' 또는 0 (기본값)
#         - columnm 명 기준 정렬(열) : 'columns' 또는 1
#     - ascending
#         - 정렬방식
#         - True(기본): 오름차순, False: 내림차순
#     - inplace
#         - 원본에 적용 여부
#         - False(기본): 변경한 복사본 반환
#         - True : 원본을 변경

# %%
import pandas as pd
import numpy as np

movie_df = pd.read_csv('data/movie.csv', index_col = 'movie_title')
movie_df.head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
# ...

# %%
movie_df.sort_index()  # axis = 'index'  ascending = True (기본값) : 행이름, 오름차순 / 원본 그대로
# Out:
#                             color        director_name  \
# movie_title
# #Horror                     Color         Tara Subkoff
# 10 Cloverfield Lane         Color     Dan Trachtenberg
# 10 Days in a Madhouse       Color        Timothy Hines
# 10 Things I Hate About You  Color           Gil Junger
# 10,000 B.C.                   NaN  Christopher Barnard
# ...                           ...                  ...
# [Rec] 2                     Color      Jaume Balagueró
# eXistenZ                    Color     David Cronenberg
# xXx                         Color            Rob Cohen
# xXx: State of the Union     Color         Lee Tamahori
# Æon Flux                    Color         Karyn Kusama
#
#                             num_critic_for_reviews  duration  \
# movie_title
# #Horror                                       35.0     101.0
# 10 Cloverfield Lane                          411.0     104.0
# 10 Days in a Madhouse                          1.0     111.0
# ...

# %%
# 문자열 : 특수문자 < 숫자 < 대문자 < 소문자 < 외국어
movie_df.sort_index(ascending = False) # 내림 차순
# Out:
#                             color        director_name  \
# movie_title
# Æon Flux                    Color         Karyn Kusama
# xXx: State of the Union     Color         Lee Tamahori
# xXx                         Color            Rob Cohen
# eXistenZ                    Color     David Cronenberg
# [Rec] 2                     Color      Jaume Balagueró
# ...                           ...                  ...
# 10,000 B.C.                   NaN  Christopher Barnard
# 10 Things I Hate About You  Color           Gil Junger
# 10 Days in a Madhouse       Color        Timothy Hines
# 10 Cloverfield Lane         Color     Dan Trachtenberg
# #Horror                     Color         Tara Subkoff
#
#                             num_critic_for_reviews  duration  \
# movie_title
# Æon Flux                                     178.0      93.0
# xXx: State of the Union                       77.0     101.0
# xXx                                          191.0     132.0
# ...

# %%
movie_df.sort_index(axis = 'columns') # 컬럼명으로 정렬
# Out:
#                                             actor_1_facebook_likes  \
# movie_title
# Avatar                                                      1000.0
# Pirates of the Caribbean: At World's End                   40000.0
# Spectre                                                    11000.0
# The Dark Knight Rises                                      27000.0
# Star Wars: Episode VII - The Force Awakens                   131.0
# ...                                                            ...
# Signed Sealed Delivered                                      637.0
# The Following                                                841.0
# A Plague So Pleasant                                           0.0
# Shanghai Calling                                             946.0
# My Date with Drew                                             86.0
#
#                                                actor_1_name  \
# movie_title
# Avatar                                          CCH Pounder
# ...

# %%
movie_df.sort_index(axis = 1, ascending = False ) # 컬럼명 기준 정렬 , 내림차순
# Out:
#                                             title_year  \
# movie_title
# Avatar                                          2009.0
# Pirates of the Caribbean: At World's End        2007.0
# Spectre                                         2015.0
# The Dark Knight Rises                           2012.0
# Star Wars: Episode VII - The Force Awakens         NaN
# ...                                                ...
# Signed Sealed Delivered                         2013.0
# The Following                                      NaN
# A Plague So Pleasant                            2013.0
# Shanghai Calling                                2012.0
# My Date with Drew                               2004.0
#
#                                                                                 plot_keywords  \
# movie_title
# Avatar                                                 avatar|future|marine|native|paraplegic
# ...

# %%
#movie_df['A':'B']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'A'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-7e73f2c47f1a> in <module>
# ----> 1 movie_df['A':'B']
#
# ...

# %%
movie_df2 = movie_df.sort_index()
movie_df2.head(5)
# Out:
#                             color        director_name  \
# movie_title
# #Horror                     Color         Tara Subkoff
# 10 Cloverfield Lane         Color     Dan Trachtenberg
# 10 Days in a Madhouse       Color        Timothy Hines
# 10 Things I Hate About You  Color           Gil Junger
# 10,000 B.C.                   NaN  Christopher Barnard
#
#                             num_critic_for_reviews  duration  \
# movie_title
# #Horror                                       35.0     101.0
# 10 Cloverfield Lane                          411.0     104.0
# 10 Days in a Madhouse                          1.0     111.0
# 10 Things I Hate About You                   133.0      97.0
# 10,000 B.C.                                    NaN      22.0
#
#                             director_facebook_likes  actor_3_facebook_likes  \
# movie_title
# #Horror                                        37.0                    56.0
# ...

# %% [markdown]
# ### **index 가 sorting 된 경우 부분값을 가지고 slicing 가능 stop 은 포함 안함**

# %%
movie_df2['A':'B'] # index 가 sorting 된 경우 시작값을 가지고 slicing 가능 stop 은 포함 안함
#A로 시작하는 영화들
# Out:
#                                        color         director_name  \
# movie_title
# A Beautiful Mind                       Color            Ron Howard
# A Beginner's Guide to Snuff            Color      Mitchell Altieri
# A Better Life                          Color           Chris Weitz
# A Bridge Too Far             Black and White  Richard Attenborough
# A Bug's Life                           Color         John Lasseter
# ...                                      ...                   ...
# Avatar                                 Color         James Cameron
# Avengers: Age of Ultron                Color           Joss Whedon
# Awake                                  Color           Joby Harold
# Away We Go                             Color            Sam Mendes
# Ayurveda: Art of Being                 Color             Pan Nalin
#
#                              num_critic_for_reviews  duration  \
# movie_title
# A Beautiful Mind                              205.0     135.0
# ...

# %%
movie_df2['A B':'A C']  # 'A B' 를 갖고있는 행을 조회
# Out:
#                                        color         director_name  \
# movie_title
# A Beautiful Mind                       Color            Ron Howard
# A Beginner's Guide to Snuff            Color      Mitchell Altieri
# A Better Life                          Color           Chris Weitz
# A Bridge Too Far             Black and White  Richard Attenborough
# A Bug's Life                           Color         John Lasseter
#
#                              num_critic_for_reviews  duration  \
# movie_title
# A Beautiful Mind                              205.0     135.0
# A Beginner's Guide to Snuff                     NaN      87.0
# A Better Life                                  94.0      98.0
# A Bridge Too Far                               56.0     175.0
# A Bug's Life                                  117.0      95.0
#
#                              director_facebook_likes  actor_3_facebook_likes  \
# movie_title
# ...

# %%
movie_df.sort_values(['duration', 'imdb_score']).head(20)
# Out:
#                                                 color        director_name  \
# movie_title
# The Touch                                       Color           Jane Clark
# Shaun the Sheep                                 Color                  NaN
# Robot Chicken                                   Color                  NaN
# Vessel                                          Color          Clark Baker
# Wal-Mart: The High Cost of Low Price            Color     Robert Greenwald
# Sabrina, the Teenage Witch                      Color                  NaN
# Anger Management                                Color                  NaN
# 10,000 B.C.                                       NaN  Christopher Barnard
# Rules of Engagement                             Color                  NaN
# Strangers with Candy                            Color                  NaN
# Home Movies                                     Color                  NaN
# ...

# %%
# duration 으로 정렬하고 duration 값이 같은것 끼리는 imdb_score 값으로 정렬 (둘다 오름차순`)
movie_df.sort_values(['duration', 'imdb_score'])[['duration', 'imdb_score']].head(20)
#movie_df.sort_values(['duration', 'imdb_score'],ascending = [False, True])[['duration', 'imdb_score']]
# Out:
#                                       duration  imdb_score
# movie_title
# The Touch                                  7.0         5.2
# Shaun the Sheep                            7.0         8.3
# Robot Chicken                             11.0         7.8
# Vessel                                    14.0         6.2
# Wal-Mart: The High Cost of Low Price      20.0         6.8
# Sabrina, the Teenage Witch                22.0         6.6
# Anger Management                          22.0         6.7
# 10,000 B.C.                               22.0         7.2
# Rules of Engagement                       22.0         7.3
# Strangers with Candy                      22.0         8.1
# Home Movies                               22.0         8.2
# It's Always Sunny in Philadelphia         22.0         8.8
# Sonny with a Chance                       23.0         6.1
# Star Wars: The Clone Wars                 23.0         7.9
# Yu-Gi-Oh! Duel Monsters                   24.0         7.0
# ...

# %%
# duration : False , imdb_score : True
movie_df.sort_values(['duration', 'imdb_score'],ascending = [False, True])[['duration', 'imdb_score']]
# Out:
#                                                duration  imdb_score
# movie_title
# Trapped                                           511.0         8.2
# Carlos                                            334.0         7.7
# Blood In, Blood Out                               330.0         8.0
# Heaven's Gate                                     325.0         6.8
# The Legend of Suriyothai                          300.0         6.6
# ...                                                 ...         ...
# Wolf Creek                                          NaN         7.1
# Black Water Transit                                 NaN         7.2
# Harry Potter and the Deathly Hallows: Part II       NaN         7.5
# Destiny                                             NaN         8.1
# War & Peace                                         NaN         8.2
#
# [4916 rows x 2 columns]

# %% [markdown]
# ### 컬럼 값 기준 정렬
# - #### sort_values(by, ascending, inplace)
#     - by
#         - 정렬기준 컬럼명
#         - 여러 컬럼에 대해 정렬할 경우 리스트에 담아 전달
#     - ascending
#         - 정렬방식
#         - True(기본): 오름차순, False: 내림차순
#         - 여러컬럼에 대해 정렬할 경우 정렬방식도 리스트에 담아 전달
#     - inplace
#         - 원본에 적용 여부
#         - False(기본): 변경한 복사본 반환
#         - True : 원본을 변경

# %%
movie_df.sort_values(by='director_name') # by t생략가능
# Out:
#                      color    director_name  num_critic_for_reviews  duration  \
# movie_title
# The Helix... Loaded  Color    A. Raven Cruz                     3.0      97.0
# Circle               Color       Aaron Hann                    29.0      87.0
# Get Low              Color  Aaron Schneider                   160.0     100.0
# Date Movie           Color    Aaron Seltzer                    99.0      85.0
# The Funeral          Color     Abel Ferrara                    48.0      99.0
# ...                    ...              ...                     ...       ...
# Heroes               Color              NaN                    75.0      60.0
# Home Movies          Color              NaN                    11.0      22.0
# Revolution           Color              NaN                    23.0      43.0
# Happy Valley         Color              NaN                    11.0      58.0
# The Following        Color              NaN                    43.0      43.0
#
# ...

# %%
movie_df.sort_values(by='director_name',ascending = False).head()  
# 결측치는 방식 (오름/내림차순)과 관계없이 마지막에 나온다.
# Out:
#                     color       director_name  num_critic_for_reviews  \
# movie_title
# Bizarre             Color       Étienne Faure                     9.0
# Sur le seuil        Color        Éric Tessier                     9.0
# Mambo Italiano      Color    Émile Gaudreault                    67.0
# The Oxford Murders  Color  Álex de la Iglesia                    71.0
# Along the Roadside  Color       Zoran Lisinac                    17.0
#
#                     duration  director_facebook_likes  actor_3_facebook_likes  \
# movie_title
# Bizarre                 98.0                     77.0                     0.0
# Sur le seuil            99.0                      0.0                     6.0
# Mambo Italiano          92.0                      9.0                    71.0
# The Oxford Murders     104.0                    275.0                   102.0
# Along the Roadside     108.0                      0.0                   142.0
#
# ...

# %%
#duration 이 250 이상인 영화들을 'num_critic_for_reviews' 칼럼 기준으로 정렬
m_df = movie_df[movie_df['duration']>=250].sort_values('num_critic_for_reviews')

# %%
m_df
# Out:
#                              color         director_name  \
# movie_title
# The Company                  Color                   NaN
# Blood In, Blood Out          Color       Taylor Hackford
# Trapped                      Color                   NaN
# Gettysburg                   Color           Ron Maxwell
# The Legend of Suriyothai     Color   Chatrichalerm Yukol
# Arn: The Knight Templar      Color          Peter Flinth
# Cleopatra                    Color  Joseph L. Mankiewicz
# Gods and Generals            Color           Ron Maxwell
# Das Boot                     Color     Wolfgang Petersen
# Heaven's Gate                Color        Michael Cimino
# Carlos                       Color                   NaN
# Once Upon a Time in America  Color          Sergio Leone
# Apocalypse Now               Color  Francis Ford Coppola
#
#                              num_critic_for_reviews  duration  \
# movie_title
# The Company                                     9.0     286.0
# ...

# %% [markdown]
# ## flights.csv (항공기 운항 기록)
# - MONTH : 비행 월
# - DAY : 비행 일
# - WEEKDAY : 비행 요일 - 1(월요일)~7(일요일)
# - AIRLINE : 항공사 코드
#      - UA:	United Air Lines Inc.
#      - AA:	American Airlines Inc.
#      - US:	US Airways Inc.
#      - F9:	Frontier Airlines Inc.
#      - B6:	JetBlue Airways
#      - OO:	Skywest Airlines Inc.
#      - AS:	Alaska Airlines Inc.
#      - NK:	Spirit Air Lines
#      - WN:	Southwest Airlines Co.
#      - DL:	Delta Air Lines Inc.
#      - EV:	Atlantic Southeast Airlines
#      - HA:	Hawaiian Airlines Inc.
#      - MQ:	American Eagle Airlines Inc.
#      - VX:	Virgin America
# - ORG_AIR : 출발공항
# - DEST_AIR : 도착공항
# - SCHED_DEP : 출발예정시각
# - DEP_DELAY : 출발지연시간(분)
# - AIR_TIME : 비행시간(분)
# - DIST : 비행거리(마일)
# - SCHED_ARR : 도착예정시각
# - ARR_DELAY : 도착지연시간(분)
# - DIVERTED : 회항여부(1: True, 0: False)
# - CANCELLED : 취소여부(1: True, 0: False)

# %%
flights = pd.read_csv('data/flights.csv')
flights.shape
# Out:
# (58492, 14)

# %%
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58492 entries, 0 to 58491
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   MONTH      58492 non-null  int64
#  1   DAY        58492 non-null  int64
#  2   WEEKDAY    58492 non-null  int64
#  3   AIRLINE    58492 non-null  object
#  4   ORG_AIR    58492 non-null  object
#  5   DEST_AIR   58492 non-null  object
#  6   SCHED_DEP  58492 non-null  int64
#  7   DEP_DELAY  57659 non-null  float64
#  8   AIR_TIME   57474 non-null  float64
#  9   DIST       58492 non-null  int64
#  10  SCHED_ARR  58492 non-null  int64
#  11  ARR_DELAY  57474 non-null  float64
#  12  DIVERTED   58492 non-null  int64
#  13  CANCELLED  58492 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 6.2+ MB

# %%
#AIRLINE의 고유값 (항공사 코드 - 범주형)
np.sort(flights['AIRLINE'].unique())
# Out:
# array(['AA', 'AS', 'B6', 'DL', 'EV', 'F9', 'HA', 'MQ', 'NK', 'OO', 'UA',
#        'US', 'VX', 'WN'], dtype=object)

# %%
flights['AIRLINE'].nunique()
# Out:
# 14

# %%
flights['AIRLINE'].value_counts().sort_index()
# Out:
# AA     8900
# AS      768
# B6      543
# DL    10601
# EV     5858
# F9     1317
# HA      112
# MQ     3471
# NK     1516
# OO     6588
# UA     7792
# US     1615
# VX      993
# WN     8418
# Name: AIRLINE, dtype: int64

# %%
flights['WEEKDAY'].value_counts().sort_index()
# Out:
# 1    8720
# 2    8535
# 3    8706
# 4    8659
# 5    8453
# 6    7052
# 7    8367
# Name: WEEKDAY, dtype: int64

# %%
flights.head(20)
# Out:
#     MONTH  DAY  WEEKDAY AIRLINE ORG_AIR DEST_AIR  SCHED_DEP  DEP_DELAY  \
# 0       1    1        4      WN     LAX      SLC       1625       58.0
# 1       1    1        4      UA     DEN      IAD        823        7.0
# 2       1    1        4      MQ     DFW      VPS       1305       36.0
# 3       1    1        4      AA     DFW      DCA       1555        7.0
# 4       1    1        4      WN     LAX      MCI       1720       48.0
# 5       1    1        4      UA     IAH      SAN       1450        1.0
# 6       1    1        4      AA     DFW      MSY       1250       84.0
# 7       1    1        4      F9     SFO      PHX       1020       -7.0
# 8       1    1        4      AA     ORD      STL       1845       -5.0
# 9       1    1        4      UA     IAH      SJC        925        3.0
# 10      1    1        4      MQ     DFW      DRO       1335       28.0
# 11      1    1        4      EV     ORD      JAN       1155        6.0
# ...

# %%
flights.tail(20)
# Out:
#        MONTH  DAY  WEEKDAY AIRLINE ORG_AIR DEST_AIR  SCHED_DEP  DEP_DELAY  \
# 58472     12   31        4      WN     PHX      HOU        845        5.0
# 58473     12   31        4      WN     DEN      PDX       1205        4.0
# 58474     12   31        4      MQ     ORD      FNT        829        4.0
# 58475     12   31        4      AA     IAH      CLT        710        1.0
# 58476     12   31        4      AA     DFW      TPA       1020       -3.0
# 58477     12   31        4      B6     DFW      BOS       1145       12.0
# 58478     12   31        4      VX     SFO      LAX       1530       29.0
# 58479     12   31        4      AA     DFW      ELP       1200        3.0
# 58480     12   31        4      OO     MSP      BIS       1310       -2.0
# 58481     12   31        4      UA     IAH      LAX       1433        1.0
# 58482     12   31        4      OO     DEN      CPR       1850       -2.0
# 58483     12   31        4      B6     PHX      BOS       2236      -12.0
# ...

# %%
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58492 entries, 0 to 58491
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   MONTH      58492 non-null  int64
#  1   DAY        58492 non-null  int64
#  2   WEEKDAY    58492 non-null  int64
#  3   AIRLINE    58492 non-null  object
#  4   ORG_AIR    58492 non-null  object
#  5   DEST_AIR   58492 non-null  object
#  6   SCHED_DEP  58492 non-null  int64
#  7   DEP_DELAY  57659 non-null  float64
#  8   AIR_TIME   57474 non-null  float64
#  9   DIST       58492 non-null  int64
#  10  SCHED_ARR  58492 non-null  int64
#  11  ARR_DELAY  57474 non-null  float64
#  12  DIVERTED   58492 non-null  int64
#  13  CANCELLED  58492 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 6.2+ MB

# %%
flights.isnull().sum()  # 결측치 개수
# Out:
# MONTH           0
# DAY             0
# WEEKDAY         0
# AIRLINE         0
# ORG_AIR         0
# DEST_AIR        0
# SCHED_DEP       0
# DEP_DELAY     833
# AIR_TIME     1018
# DIST            0
# SCHED_ARR       0
# ARR_DELAY    1018
# DIVERTED        0
# CANCELLED       0
# dtype: int64

# %% [markdown]
# ## 기술통계함수를 이용한 데이터 집계
# ### 주요 기술통계 함수
#
# |함수|설명|
# |-|-|
# |sum()|합계|
# |mean()|평균|
# |median()|중위수|
# |quantile()|분위수|
# |std()|표준편차|
# |var()|분산|
# |count()|결측치를 제외한 원소 개수|
# |min()|최소값|
# |max()|최대값|
# |argmax()|최대값 index|
# |argmin()|최소값 index|
# |unique()|고유값|
# |nunique()|고유값의 개수|
#
# - DataFrame에 적용할 경우 컬럼별로 계산
# - sum(), max(), min(), unique(), nunique(), count()는 문자열에 적용가능
#      - 문자열 컬럼의 min/max index를 조회하려면 np.argmax(),np.argmin()을 사용
# - 기본적으로 결측치(NA)는 제외하고 처리한다.
#     - 결측치 제외하지 않으려면 skipna=False로 설정

# %%
flights['AIRLINE'].sum()  # 모든 컬럼의 값을 더함
# Out:
# '...'

# %%
flights.sum()# 컬럼별로 처리
# Out:
# MONTH                                                   363858
# DAY                                                     918447
# WEEKDAY                                                 229690
# AIRLINE      WNUAMQAAWNUAAAF9AAUAMQEVOOEVUAAAOONKMQWNWNUAOO...
# ORG_AIR      LAXDENDFWDFWLAXIAHDFWSFOORDIAHDFWORDORDORDIAHD...
# DEST_AIR     SLCIADVPSDCAMCISANMSYPHXSTLSJCDROJANMSPCMHINDD...
# SCHED_DEP                                             81186009
# DEP_DELAY                                               629705
# AIR_TIME                                           6.66288e+06
# DIST                                                  51057671
# SCHED_ARR                                             90627495
# ARR_DELAY                                               334057
# DIVERTED                                                   137
# CANCELLED                                                  881
# dtype: object

# %%
flights['AIRLINE'].mean() # 문자열이라 안됨
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1426         try:
# -> 1427             x = float(x)
#    1428         except ValueError:
#
# ValueError: could not convert string to float: '...'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1430             try:
# -> 1431                 x = complex(x)
#    1432             except ValueError as err:
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-7997c13be548> in <module>
# ...

# %%
flights.mean() # mean(), std(),var() 은 숫자형만 계산해준다.
# Out:
# MONTH           6.220646
# DAY            15.702096
# WEEKDAY         3.926862
# SCHED_DEP    1387.984836
# DEP_DELAY      10.921192
# AIR_TIME      115.928576
# DIST          872.900072
# SCHED_ARR    1549.399832
# ARR_DELAY       5.812315
# DIVERTED        0.002342
# CANCELLED       0.015062
# dtype: float64

# %%
flights.select_dtypes(exclude=['object']).sum()  # 결측치가 있어도 빼고 그냥 계산해준다.
# Out:
# MONTH          363858.0
# DAY            918447.0
# WEEKDAY        229690.0
# SCHED_DEP    81186009.0
# DEP_DELAY      629705.0
# AIR_TIME      6662879.0
# DIST         51057671.0
# SCHED_ARR    90627495.0
# ARR_DELAY      334057.0
# DIVERTED          137.0
# CANCELLED         881.0
# dtype: float64

# %%
flights.mean(skipna=False)
# Out:
# MONTH           6.220646
# DAY            15.702096
# WEEKDAY         3.926862
# SCHED_DEP    1387.984836
# DEP_DELAY            NaN
# AIR_TIME             NaN
# DIST          872.900072
# SCHED_ARR    1549.399832
# ARR_DELAY            NaN
# DIVERTED        0.002342
# CANCELLED       0.015062
# dtype: float64

# %%
flights['DIST'].mean()
# Out:
# 872.9000718046913

# %%
flights.describe()
# Out:
#               MONTH           DAY       WEEKDAY     SCHED_DEP     DEP_DELAY  \
# count  58492.000000  58492.000000  58492.000000  58492.000000  57659.000000
# mean       6.220646     15.702096      3.926862   1387.984836     10.921192
# std        3.358484      8.760846      1.995777    482.810792     36.146210
# min        1.000000      1.000000      1.000000      5.000000    -24.000000
# 25%        3.000000      8.000000      2.000000   1000.000000     -4.000000
# 50%        6.000000     16.000000      4.000000   1353.000000     -1.000000
# 75%        9.000000     23.000000      6.000000   1805.000000     10.000000
# max       12.000000     31.000000      7.000000   2359.000000   1194.000000
#
#            AIR_TIME          DIST     SCHED_ARR     ARR_DELAY      DIVERTED  \
# count  57474.000000  58492.000000  58492.000000  57474.000000  58492.000000
# mean     115.928576    872.900072   1549.399832      5.812315      0.002342
# ...

# %%
flights.describe(include ='object')
# Out:
#        AIRLINE ORG_AIR DEST_AIR
# count    58492   58492    58492
# unique      14      10      271
# top         DL     ATL      LAX
# freq     10601   10413     1991

# %% [markdown]
# |함수|설명|
# |-|-|
# |sum()|합계|
# |mean()|평균|
# |median()|중위수|
# |quantile()|분위수|
# |std()|표준편차|
# |var()|분산|
# |count()|결측치를 제외한 원소 개수|
# |min()|최소값|
# |max()|최대값|
# |idxmax()|최대값 index|
# |idxmin()|최소값 index|
# |unique()|고유값|
# |nunique()|고유값의 개수|

# %% [markdown]
# *abc*

# %% [markdown]
# ### aggregate(func, axis=0, \*args, \*\*kwargs) 또는 agg(func, axis=0, \*args, \*\*kwargs)
# - 판다스가 제공하는 집계 함수들이나 사용자 정의 집계함수를 DataFrame의 열 별로 처리해주는 함수.
# - **사용자 정의 집계함수를 사용하거나 열 별로 다른 집계를 할 때 사용한다.**
# - 매개변수
#     - func
#         - 집계 함수 지정
#             - 문자열/문자열리스트 : 집계함수의 이름('mean','sum'등 으로 ).
#                 여러 개일 경우 리스트. 판다스 제공 집계함수는 문자열로 함수명만 제공가능
#             - 딕션너리 : {집계할컬럼 : 집계함수 } : 컬럼별로 다른 집게함수를 사용할때
#             - 함수 객체 : 사용자 정의 함수의 경우 함수이름을 전달 : 문자열 넣는 방식이아니라 그냥 (따옴표 빼고 )
#     - axis
#         - 0 또는 'index' (기본값): 컬럼 별 집계
#         - 1 또는 'columns': 행 별 집계
#     - \*args, \**kwargs
#         - 함수에 전달할 매개변수.
#         - 집계함수는 첫번째 매개변수로 Series를 받는다. 그 이외의 매개변수가 있는 경우.

# %%
# 평균
flights.aggregate('mean')  #
# Out:
# MONTH           6.220646
# DAY            15.702096
# WEEKDAY         3.926862
# SCHED_DEP    1387.984836
# DEP_DELAY      10.921192
# AIR_TIME      115.928576
# DIST          872.900072
# SCHED_ARR    1549.399832
# ARR_DELAY       5.812315
# DIVERTED        0.002342
# CANCELLED       0.015062
# dtype: float64

# %%
#평균 , 합계를 같이 보고싶음 
flights.aggregate(['mean','sum']).T  # 여러개의 기술 통계함수를 보고싶다.
# Out:
#                 mean                                                sum
# MONTH        6.22065                                             363858
# DAY          15.7021                                             918447
# WEEKDAY      3.92686                                             229690
# AIRLINE          NaN  WNUAMQAAWNUAAAF9AAUAMQEVOOEVUAAAOONKMQWNWNUAOO...
# ORG_AIR          NaN  LAXDENDFWDFWLAXIAHDFWSFOORDIAHDFWORDORDORDIAHD...
# DEST_AIR         NaN  SLCIADVPSDCAMCISANMSYPHXSTLSJCDROJANMSPCMHINDD...
# SCHED_DEP    1387.98                                         8.1186e+07
# DEP_DELAY    10.9212                                             629705
# AIR_TIME     115.929                                        6.66288e+06
# DIST           872.9                                        5.10577e+07
# SCHED_ARR     1549.4                                        9.06275e+07
# ARR_DELAY    5.81232                                             334057
# ...

# %%
flights['DIST'].agg(['sum','mean','count','median'])
# Out:
# sum       5.105767e+07
# mean      8.729001e+02
# count     5.849200e+04
# median    6.900000e+02
# Name: DIST, dtype: float64

# %%
flights.select_dtypes(exclude=['object']).agg(['sum','mean','count','median']).T
# Out:
#                   sum         mean    count  median
# MONTH        363858.0     6.220646  58492.0     6.0
# DAY          918447.0    15.702096  58492.0    16.0
# WEEKDAY      229690.0     3.926862  58492.0     4.0
# SCHED_DEP  81186009.0  1387.984836  58492.0  1353.0
# DEP_DELAY    629705.0    10.921192  57659.0    -1.0
# AIR_TIME    6662879.0   115.928576  57474.0    97.0
# DIST       51057671.0   872.900072  58492.0   690.0
# SCHED_ARR  90627495.0  1549.399832  58492.0  1603.0
# ARR_DELAY    334057.0     5.812315  57474.0    -4.0
# DIVERTED        137.0     0.002342  58492.0     0.0
# CANCELLED       881.0     0.015062  58492.0     0.0

# %%
#AIRLIN:최빈값-mode, DEP_DELAY: 평균 - MEAN / 컬럼별 다른 기술통계함수 적용
flights.agg({'AIRLINE':'mode','DEP_DELAY':'mean'})
# Out:
#   AIRLINE  DEP_DELAY
# 0      DL  10.921192

# %%
#AIRLIN:최빈값-mode, DEP_DELAY: 평균 - MEAN, 표준편차 -std
flights.agg({'AIRLINE':'mode','DEP_DELAY':['mean','std']})
# Out:
#      AIRLINE  DEP_DELAY
#         mode  DEP_DELAY
# 0         DL        NaN
# mean     NaN  10.921192
# std      NaN  36.146210

# %%
# ARR_DELAY, DEP_DELAY의 min, max // 여러 컬럼의 같은 통계함수 적용
flights[['ARR_DELAY','DEP_DELAY']].agg(['min','max'])
# Out:
#      ARR_DELAY  DEP_DELAY
# min      -60.0      -24.0
# max     1185.0     1194.0

# %%
flights['ARR_DELAY'].quantile(q=[0.25,0.75])  # 분위수 - 기본 : 중앙값
# Out:
# 0.25   -12.0
# 0.75     9.0
# Name: ARR_DELAY, dtype: float64

# %% [markdown]
# **agg(func, axis=0, *args, **kwargs)**

# %%
flights['ARR_DELAY'].agg('quantile',q=[0.25,0.75])  # 통계함수가 매개 변수를 갖고 있다면 여러개의 함수를 적용 못한다.
                                                    # 자리를 맞추기 위해서 axis 값도 넣어야하고 불편하니까 
                                                    # 통게함수가 매개 변수를 갖고 있다면 keyword 인자로 넣어 줘야 한다.
        
                                                    #flights.agg(func=quantile, axis=0, *args=q=[0.25,0.75], **kwargs)
# Out:
# 0.25   -12.0
# 0.75     9.0
# Name: ARR_DELAY, dtype: float64

# %% [markdown]
# # Groupby
# - 특정 열을 기준으로 데이터셋을 묶는다.
# - ~~ 별 집계를 할 때 사용한다.
# - 구문
#     - DF.groupby('그룹으로묶을기준컬럼')['집계할 컬럼'].집계함수() : ex) airline 이면 같은 airline 끼리 그룹을 한다음에~!
#         - 집계할 컬럼은 Fancy Indexing 으로 지정(리스트, 튜플로 전달)
#     - 집계함수
#         - 기술통계 함수들
#         - agg()/aggregate()
#             - 여러 다른 집계함수 호출시(여러 집계를 같이 볼경우)
#             - 사용자정의 집계함수 호출시
#             - 컬럼별로 다른 집계함수들을 호출할 경우

# %% [markdown]
# - ### 가장 많이 쓰이는 것은 마지막 집계함수를 직접 호출 하는 것
# - ### 한번에 여러개의 집계함수를 호출 할 경우는 agg([리스트]) 를 사용한다.
# - ### 열별로 다른 집계를 하는 경우 dict를 사용한다.

# %%
np.sort(flights['AIRLINE'].unique())
# Out:
# array(['AA', 'AS', 'B6', 'DL', 'EV', 'F9', 'HA', 'MQ', 'NK', 'OO', 'UA',
#        'US', 'VX', 'WN'], dtype=object)

# %%
# 같은 항공사끼리 grouping
gb = flights.groupby('AIRLINE') 
type(gb)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
from pprint import pprint
pprint(gb.groups)
# Out:
# {'AA': Int64Index([    3,     6,     8,    15,    26,    32,    33,    36,    37,
#                41,
#             ...
#             58454, 58456, 58462, 58465, 58466, 58470, 58475, 58476, 58479,
#             58487],
#            dtype='int64', length=8900),
#  'AS': Int64Index([   38,   198,   241,   277,   397,   450,   453,   500,   518,
#               591,
#             ...
#             58202, 58207, 58224, 58238, 58253, 58305, 58355, 58404, 58407,
#             58428],
#            dtype='int64', length=768),
#  'B6': Int64Index([  123,   127,   239,   333,   548,   549,   696,   757,   945,
#              1175,
#             ...
#             57948, 57968, 58059, 58076, 58228, 58262, 58301, 58425, 58477,
#             58483],
#            dtype='int64', length=543),
#  'DL': Int64Index([   53,    57,    77,    79,    85,    90,    91,   101,   116,
#               117,
#             ...
#             58390, 58411, 58413, 58421, 58429, 58440, 58448, 58464, 58467,
# ...

# %%
flights.iloc[[3,6,8,15,26,32,33,36,37,41,]]  #구조 확인
# Out:
#     MONTH  DAY  WEEKDAY AIRLINE ORG_AIR DEST_AIR  SCHED_DEP  DEP_DELAY  \
# 3       1    1        4      AA     DFW      DCA       1555        7.0
# 6       1    1        4      AA     DFW      MSY       1250       84.0
# 8       1    1        4      AA     ORD      STL       1845       -5.0
# 15      1    1        4      AA     DEN      DFW       1445       -6.0
# 26      1    1        4      AA     LAX      AUS       1430       33.0
# 32      1    1        4      AA     PHX      MIA       1559      115.0
# 33      1    1        4      AA     IAH      MIA       1935       26.0
# 36      1    1        4      AA     DFW      OKC       1345        5.0
# 37      1    1        4      AA     LAS      DFW       1210       12.0
# 41      1    1        4      AA     DFW      DCA       2010       19.0
#
#     AIR_TIME  DIST  SCHED_ARR  ARR_DELAY  DIVERTED  CANCELLED
# 3      126.0  1192       1935       -7.0         0          0
# 6       64.0   447       1410       83.0         0          0
# ...

# %%
flights[flights['AIRLINE']=='AA']
# Out:
#        MONTH  DAY  WEEKDAY AIRLINE ORG_AIR DEST_AIR  SCHED_DEP  DEP_DELAY  \
# 3          1    1        4      AA     DFW      DCA       1555        7.0
# 6          1    1        4      AA     DFW      MSY       1250       84.0
# 8          1    1        4      AA     ORD      STL       1845       -5.0
# 15         1    1        4      AA     DEN      DFW       1445       -6.0
# 26         1    1        4      AA     LAX      AUS       1430       33.0
# ...      ...  ...      ...     ...     ...      ...        ...        ...
# 58470     12   31        4      AA     DFW      FAT       1020       -3.0
# 58475     12   31        4      AA     IAH      CLT        710        1.0
# 58476     12   31        4      AA     DFW      TPA       1020       -3.0
# 58479     12   31        4      AA     DFW      ELP       1200        3.0
# 58487     12   31        4      AA     SFO      DFW        515        5.0
#
#        AIR_TIME  DIST  SCHED_ARR  ARR_DELAY  DIVERTED  CANCELLED
# ...

# %%
# AIRLINE 별 각 컬럼의 평균
flights.groupby('AIRLINE').mean()
# Out:
#             MONTH        DAY   WEEKDAY    SCHED_DEP  DEP_DELAY    AIR_TIME  \
# AIRLINE
# AA       6.661461  15.570562  3.986966  1340.140449  11.274057  144.259404
# AS       6.197917  15.247396  3.941406  1418.269531   1.808594  147.845052
# B6       6.368324  15.788214  4.040516  1512.924494  14.287823  209.412963
# DL       6.277332  15.721158  3.913310  1426.563154   7.242450  115.334187
# EV       6.003926  15.866166  3.927450  1415.510413   9.092625   68.964016
# F9       6.401670  15.914958  4.007593  1407.121488  14.310398  127.592337
# HA       5.508929  15.526786  3.750000   959.419643   2.571429  338.288288
# MQ       5.970614  15.598963  3.902622  1432.251801  11.094323   61.318346
# NK       6.602243  15.680739  4.006596  1336.634565  19.514401  135.736878
# OO       6.134791  15.651943  3.923345  1426.486794   9.662279   76.010272
# UA       6.322510  15.697510  3.871535  1357.970739  16.210485  155.650521
# ...

# %%
# AIRLINE 별 AIR_TIME 의 평균
np.round(flights.groupby('AIRLINE')['AIR_TIME'].mean(),2)
# Out:
# AIRLINE
# AA    144.26
# AS    147.85
# B6    209.41
# DL    115.33
# EV     68.96
# F9    127.59
# HA    338.29
# MQ     61.32
# NK    135.74
# OO     76.01
# UA    155.65
# US    147.69
# VX    154.86
# WN    107.01
# Name: AIR_TIME, dtype: float64

# %% [markdown]
# SELECT AVG(AIR_TIME)
# from flights
# group by AIRLINE

# %%
flights.groupby('AIRLINE')[['ARR_DELAY','DEP_DELAY']].mean()
# Out:
#          ARR_DELAY  DEP_DELAY
# AIRLINE
# AA        5.542661  11.274057
# AS       -0.833333   1.808594
# B6        8.692593  14.287823
# DL        0.339691   7.242450
# EV        7.034580   9.092625
# F9       13.630651  14.310398
# HA        4.972973   2.571429
# MQ        6.860591  11.094323
# NK       18.436070  19.514401
# OO        7.593463   9.662279
# UA        7.765755  16.210485
# US        1.681105   4.361355
# VX        5.348884   8.918946
# WN        6.397353  12.639366

# %%
flights.groupby('AIRLINE')['ARR_DELAY','DEP_DELAY'].mean()
# FutureWarning   : 앞으로 수정할때 없어질 수도 있다는 경고문
# Out:
# <ipython-input-170-a481425a788a>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   flights.groupby('AIRLINE')['ARR_DELAY','DEP_DELAY'].mean()
#          ARR_DELAY  DEP_DELAY
# AIRLINE
# AA        5.542661  11.274057
# AS       -0.833333   1.808594
# B6        8.692593  14.287823
# DL        0.339691   7.242450
# EV        7.034580   9.092625
# F9       13.630651  14.310398
# HA        4.972973   2.571429
# MQ        6.860591  11.094323
# NK       18.436070  19.514401
# OO        7.593463   9.662279
# UA        7.765755  16.210485
# US        1.681105   4.361355
# VX        5.348884   8.918946
# WN        6.397353  12.639366

# %%
#AIRLINE 별 ARR_DELAY의 평균,표준편차
flights.groupby('AIRLINE')['ARR_DELAY'].agg(['mean','std'])
# Out:
#               mean        std
# AIRLINE
# AA        5.542661  43.323160
# AS       -0.833333  31.168354
# B6        8.692593  40.221718
# DL        0.339691  32.299471
# EV        7.034580  36.682336
# F9       13.630651  53.030912
# HA        4.972973  37.528283
# MQ        6.860591  36.324657
# NK       18.436070  48.727259
# OO        7.593463  35.331344
# UA        7.765755  46.405935
# US        1.681105  27.030227
# VX        5.348884  33.747675
# WN        6.397353  32.610666

# %%
#AIRLINE 별 ARR_DELAY,DEP_DELAY,AIR_TIME의 평균과 표준 편차를 변수 RESULT에 넣기 
result = flights.groupby('AIRLINE')[['ARR_DELAY','DEP_DELAY','AIR_TIME']].agg(['mean','std'])
result
# Out:
#          ARR_DELAY             DEP_DELAY               AIR_TIME
#               mean        std       mean        std        mean         std
# AIRLINE
# AA        5.542661  43.323160  11.274057  40.787806  144.259404   72.871103
# AS       -0.833333  31.168354   1.808594  29.543702  147.845052   59.821928
# B6        8.692593  40.221718  14.287823  36.863416  209.412963   97.466125
# DL        0.339691  32.299471   7.242450  29.759377  115.334187   71.027396
# EV        7.034580  36.682336   9.092625  34.582917   68.964016   31.735348
# F9       13.630651  53.030912  14.310398  51.773844  127.592337   46.832304
# HA        4.972973  37.528283   2.571429  33.880743  338.288288   29.329906
# MQ        6.860591  36.324657  11.094323  31.159293   61.318346   29.409990
# NK       18.436070  48.727259  19.514401  46.484632  135.736878   57.031164
# OO        7.593463  35.331344   9.662279  33.413767   76.010272   42.394403
# ...

# %%
result['ARR_DELAY']
# Out:
#               mean        std
# AIRLINE
# AA        5.542661  43.323160
# AS       -0.833333  31.168354
# B6        8.692593  40.221718
# DL        0.339691  32.299471
# EV        7.034580  36.682336
# F9       13.630651  53.030912
# HA        4.972973  37.528283
# MQ        6.860591  36.324657
# NK       18.436070  48.727259
# OO        7.593463  35.331344
# UA        7.765755  46.405935
# US        1.681105  27.030227
# VX        5.348884  33.747675
# WN        6.397353  32.610666

# %%
result['ARR_DELAY','mean']#['AA']#
# Out:
# AIRLINE
# AA     5.542661
# AS    -0.833333
# B6     8.692593
# DL     0.339691
# EV     7.034580
# F9    13.630651
# HA     4.972973
# MQ     6.860591
# NK    18.436070
# OO     7.593463
# UA     7.765755
# US     1.681105
# VX     5.348884
# WN     6.397353
# Name: (ARR_DELAY, mean), dtype: float64

# %%
# 컬럼별로 다른 통게량을 조회 
# AIRLINE 별 DEP_DLELAY 평균,표준편차, ARR_DELAY 최소,최대값, AIR_TIME COUNT
flights.groupby('AIRLINE').agg({'DEP_DELAY':['mean','std'], 
                                'ARR_DELAY':['min','max'],
                                 'AIR_TIME':['count']})
# Out:
#          DEP_DELAY            ARR_DELAY         AIR_TIME
#               mean        std       min     max    count
# AIRLINE
# AA       11.274057  40.787806     -60.0   858.0     8720
# AS        1.808594  29.543702     -57.0   344.0      768
# B6       14.287823  36.863416     -51.0   331.0      540
# DL        7.242450  29.759377     -57.0   741.0    10539
# EV        9.092625  34.582917     -39.0   669.0     5697
# F9       14.310398  51.773844     -43.0   839.0     1305
# HA        2.571429  33.880743     -44.0   298.0      111
# MQ       11.094323  31.159293     -37.0   357.0     3314
# NK       19.514401  46.484632     -39.0   474.0     1486
# OO        9.662279  33.413767     -44.0   724.0     6425
# UA       16.210485  44.834336     -58.0  1185.0     7680
# US        4.361355  24.550930     -51.0   431.0     1593
# VX        8.918946  31.782085     -51.0   236.0      986
# WN       12.639366  30.506549     -52.0   493.0     8310

# %%
# 취소여부 : 0- False(취소 안됨), 1- True (취소)
flights['CANCELLED'].value_counts()
# Out:
# 0    57611
# 1      881
# Name: CANCELLED, dtype: int64

# %%
flights.groupby('AIRLINE')['CANCELLED'].count()  #-->그룹별 데이터 더한 값
# Out:
# AIRLINE
# AA     8900
# AS      768
# B6      543
# DL    10601
# EV     5858
# F9     1317
# HA      112
# MQ     3471
# NK     1516
# OO     6588
# UA     7792
# US     1615
# VX      993
# WN     8418
# Name: CANCELLED, dtype: int64

# %%
flights['CANCELLED'].count() #13  CANCELLED  58492 non-null  int64
# Out:
# 58492

# %%
flights['CANCELLED'].sum() # 취소 건수
# Out:
# 881

# %%
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58492 entries, 0 to 58491
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   MONTH      58492 non-null  int64
#  1   DAY        58492 non-null  int64
#  2   WEEKDAY    58492 non-null  int64
#  3   AIRLINE    58492 non-null  object
#  4   ORG_AIR    58492 non-null  object
#  5   DEST_AIR   58492 non-null  object
#  6   SCHED_DEP  58492 non-null  int64
#  7   DEP_DELAY  57659 non-null  float64
#  8   AIR_TIME   57474 non-null  float64
#  9   DIST       58492 non-null  int64
#  10  SCHED_ARR  58492 non-null  int64
#  11  ARR_DELAY  57474 non-null  float64
#  12  DIVERTED   58492 non-null  int64
#  13  CANCELLED  58492 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 6.2+ MB

# %%
# 항공사별 취소 건수 
flights.groupby('AIRLINE')['CANCELLED'].sum() # 0,1 로 이루어진, true,false 인 데이터 중 개수를 구할때
# Out:
# AIRLINE
# AA    154
# AS      0
# B6      1
# DL     38
# EV    146
# F9     10
# HA      0
# MQ    152
# NK     25
# OO    142
# UA     93
# US     21
# VX      6
# WN     93
# Name: CANCELLED, dtype: int64

# %%
# index기준으로 groupby 
# df.gropby(df.index)
df = pd.DataFrame(np.arange(15).reshape(5,3), index = ['A','A','A','B','B'], columns =['가','나','다'])
df
# Out:
#     가   나   다
# A   0   1   2
# A   3   4   5
# A   6   7   8
# B   9  10  11
# B  12  13  14

# %%
# index명이 같은 index 끼리 group
df.index
# Out:
# Index(['A', 'A', 'A', 'B', 'B'], dtype='object')

# %%
df.groupby(df.index).mean()
# Out:
#       가     나     다
# A   3.0   4.0   5.0
# B  10.5  11.5  12.5

# %% [markdown]
# select 집계
# from 테이블
# group by 컬럼1,컬럼2

# %% [markdown]
# ###  복수열 기준 그룹핑
# - 두개 이상의 열을 그룹으로 묶을 수 있다.
# - groupby의 매개변수에 그룹으로 묶을 컬럼들의 이름을 리스트로 전달한다.

# %%
# AIRLINE, MONTH 기준 평균
flights.groupby(['AIRLINE', 'MONTH'])['DEP_DELAY'].mean()  # multi index
# Out:
# AIRLINE  MONTH
# AA       1        12.645740
#          2         8.485816
#          3        13.536337
#          4         9.127352
#          5        12.552995
#                     ...
# WN       7        18.904110
#          8        12.123253
#          9         6.240152
#          11        8.548344
#          12       14.622222
# Name: DEP_DELAY, Length: 149, dtype: float64

# %%
# AIRLINE,MONTH 별 DEP_DELAY,ARR_DELAY 평균
flights.groupby(['AIRLINE', 'MONTH'])[['DEP_DELAY','ARR_DELAY']].mean()
# Out:
#                DEP_DELAY  ARR_DELAY
# AIRLINE MONTH
# AA      1      12.645740   9.436282
#         2       8.485816   6.262032
#         3      13.536337  10.639535
#         4       9.127352   1.503628
#         5      12.552995   7.549231
# ...                  ...        ...
# WN      7      18.904110  13.458750
#         8      12.123253   6.542675
#         9       6.240152  -1.232824
#         11      8.548344   1.846154
#         12     14.622222   8.947575
#
# [149 rows x 2 columns]

# %%
#AIRLINE,MONTH 별로 DEP_DELAY,ARR_DELAY 의 평균 총합/
#AIRLINE,MONTH 별로 DEP_DELAY 평균, 총합,ARR_DELAY 표준편차
result=flights.groupby(['AIRLINE', 'MONTH'])[['DEP_DELAY','ARR_DELAY']].agg(['mean','sum']) 
result# 컬럼별로 다른것을 조회할때는 dic 형태로
# Out:
#                DEP_DELAY           ARR_DELAY
#                     mean      sum       mean      sum
# AIRLINE MONTH
# AA      1      12.645740   8460.0   9.436282   6294.0
#         2       8.485816   4786.0   6.262032   3513.0
#         3      13.536337   9313.0  10.639535   7320.0
#         4       9.127352   6307.0   1.503628   1036.0
#         5      12.552995   8172.0   7.549231   4907.0
# ...                  ...      ...        ...      ...
# WN      7      18.904110  15180.0  13.458750  10767.0
#         8      12.123253   9541.0   6.542675   5136.0
#         9       6.240152   4911.0  -1.232824   -969.0
#         11      8.548344   6454.0   1.846154   1392.0
#         12     14.622222  11186.0   8.947575   6827.0
#
# [149 rows x 4 columns]

# %%
result.loc['AA']
# Out:
#        DEP_DELAY           ARR_DELAY
#             mean      sum       mean     sum
# MONTH
# 1      12.645740   8460.0   9.436282  6294.0
# 2       8.485816   4786.0   6.262032  3513.0
# 3      13.536337   9313.0  10.639535  7320.0
# 4       9.127352   6307.0   1.503628  1036.0
# 5      12.552995   8172.0   7.549231  4907.0
# 6      17.547684  12880.0   9.968493  7277.0
# 7      13.305985  13785.0   6.959302  7182.0
# 8      11.137295  10870.0   3.289990  3188.0
# 9       6.205819   5759.0  -0.544276  -504.0
# 11     10.916575   9945.0   4.450441  4041.0
# 12      9.280488   8371.0   4.531111  4078.0

# %%
result.loc['AA',12]  # 멀티 인덱스
# Out:
# DEP_DELAY  mean       9.280488
#            sum     8371.000000
# ARR_DELAY  mean       4.531111
#            sum     4078.000000
# Name: (AA, 12), dtype: float64

# %%
result['DEP_DELAY','mean'] # 멀티 columns
# Out:
# AIRLINE
# AA    11.274057
# AS     1.808594
# B6    14.287823
# DL     7.242450
# EV     9.092625
# F9    14.310398
# HA     2.571429
# MQ    11.094323
# NK    19.514401
# OO     9.662279
# UA    16.210485
# US     4.361355
# VX     8.918946
# WN    12.639366
# Name: (DEP_DELAY, mean), dtype: float64

# %%
select
from   emp
group by dept
having avg(salary) > 10000

# %% [markdown]
# ## Goupby 집계후 집계한 것 중 특정 조건의 항목만 보기
# - SQL having 절
# - 집계 후 boolean indexing으로 having절 처리

# %%
# 항공사별로 취소한 횟수가 50건 이상인 것만 조회 (취소:True =1)
result= flights.groupby('AIRLINE')['CANCELLED'].sum()  # having 절을 먼저 만들고  이것을 갖고 블리언 인덱싱을 만든다.
result[result>=50]
# Out:
# AIRLINE
# AA    154
# EV    146
# MQ    152
# OO    142
# UA     93
# WN     93
# Name: CANCELLED, dtype: int64

# %% [markdown]
# ## 사용자 정의 집계함수를 만들어 적용
#
# ### 사용자 정의 집계 함수 정의
# - 매개변수
#     1. Series 또는 DataFrame을 받을 매개변수(필수)
#     2. 필요한 값을 받을 매개변수를 선언한다. (선택)
#
# ### agg() 를 사용해 사용자 정의 집계 함수 호출
# - DataFrame.agg(func=None, axis=0, \*args, \*\*kwargs)
#     - axis : 사용자 정의 함수에 전달할 값들(Series)의 축 지정
# - Series.agg(func=None, axis=0, \*args, \*\*kwargs)
#     - DataFrame의 agg와 매개변수 구조를 맞추기 위해 axis 지정한다.
# - SeriesGroupBy.agg(func=None,  *args, **kwargs)
#     - axis 지정안함
#     - 사용자 함수에 Series를 group 별로 전달한다.
# - DataFrameGroupBy.agg(func, *args, **kwargs)
#     - axis 지정안함.
#     - 사용자 함수에 Series를 group 별로 전달한다.
# - *args, **kwargs는 사용자 정의 함수에 선언한 매개변수가 있을 경우 전달할 값을 전달한다.

# %%
# max 와 min 값의 차이를 반환하는 사용자정의 집계함수 
def max_min_diff(x):
    """
    # max 와 min 값의 차이를 반환하는 사용자정의 집계함수 
    [매개변수]
        x: 통계량을 구할 Series
    [반환값]
        max()-min()
        Series x의 타입이 object(문자열)이면 None을 반환
    """
    if  x.dtype == 'object':
        return None
    return x.max()-x.min()

# %%
flights['ARR_DELAY'] # 시리즈로 반환함
# Out:
# 0        65.0
# 1       -13.0
# 2        35.0
# 3        -7.0
# 4        39.0
#          ...
# 58487   -19.0
# 58488     4.0
# 58489    -5.0
# 58490    34.0
# 58491    -1.0
# Name: ARR_DELAY, Length: 58492, dtype: float64

# %%
max_min_diff(flights['ARR_DELAY'])
# Out:
# 1245.0

# %%
flights['ARR_DELAY'].agg(max_min_diff) # 사용자정의 집계함수 객체를 매개변수로 전달
# Out:
# 1245.0

# %%
flights['ARR_DELAY'].agg(['max','min',max_min_diff]) # 사용자정의 함수를 매개변수로 넣을때는 따옴표 필요없음.
# Out:
# max             1185.0
# min              -60.0
# max_min_diff    1245.0
# Name: ARR_DELAY, dtype: float64

# %%
flights.agg(['max','min',max_min_diff]) # 전체 컬럼의 max , min , max_min_diff
# Out:
#               MONTH  DAY  WEEKDAY AIRLINE ORG_AIR DEST_AIR  SCHED_DEP  \
# max              12   31        7      WN     SFO      YUM       2359
# min               1    1        1      AA     ATL      ABE          5
# max_min_diff     11   30        6    None    None     None       2354
#
#               DEP_DELAY  AIR_TIME  DIST  SCHED_ARR  ARR_DELAY  DIVERTED  \
# max              1194.0     577.0  4502       2359     1185.0         1
# min               -24.0       8.0    67          1      -60.0         0
# max_min_diff     1218.0     569.0  4435       2358     1245.0         1
#
#               CANCELLED
# max                   1
# min                   0
# max_min_diff          1

# %%
flights.groupby('AIRLINE').agg(max_min_diff)
# Out:
#          MONTH  DAY  WEEKDAY ORG_AIR DEST_AIR  SCHED_DEP  DEP_DELAY  AIR_TIME  \
# AIRLINE
# AA          11   30        6    None     None       2354      850.0     484.0
# AS          11   30        6    None     None       1755      360.0     344.0
# B6          11   30        6    None     None       1819      367.0     304.0
# DL          11   30        6    None     None       2354      772.0     555.0
# EV          11   30        6    None     None       1712      689.0     198.0
# F9          11   30        6    None     None       2354      871.0     241.0
# HA          11   30        6    None     None       1680      322.0     130.0
# MQ          11   30        6    None     None       1845      354.0     183.0
# NK          11   30        6    None     None       2345      477.0     256.0
# OO          11   30        6    None     None       2352      755.0     250.0
# UA          11   30        6    None     None       2352     1212.0     519.0
# ...

# %%
# 매개변수가 있는 사용자 정의 집계함수.
# max가 100 이상인지 여부
def check_max(series, n=100):
    if series.dtype != 'object':
        return series.max() >= n # n 이상인지 boolean 값으로 True, False 로 반환

# %%
flights['ARR_DELAY'].max()
# Out:
# 1185.0

# %%
check_max(flights['ARR_DELAY'], n =2000)
# Out:
# False

# %%
flights['ARR_DELAY'].agg(check_max)
# Out:
# True

# %%
flights['ARR_DELAY'].max()
# Out:
# 1185.0

# %%
flights['ARR_DELAY'].agg(check_max, n= 2000)
# Out:
# False

# %%
flights['ARR_DELAY'].agg(check_max,2000) 
# 문법상 axis 자리에 2000 이 들어가서 error // groouupby 하면서 함수를 쓸때 문법 헷갈리니까 매개변수(keyword인자)로 하는 것이 낫다.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     367         try:
# --> 368             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     369         except KeyError:
#
# KeyError: 2000
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-190-8ae9b0e4c0aa> in <module>
# ----> 1 flights['ARR_DELAY'].agg(check_max,2000)
#       2 # 문법상 axis 자리에 2000 이 들어가서 error // groouupby 하면서 함수를 쓸때 문법 헷갈리니까 매개변수로 하는 것이 낫다.
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in aggregate(self, func, axis, *args, **kwargs)
#    4028     def aggregate(self, func=None, axis=0, *args, **kwargs):
#    4029         # Validate the axis parameter
# -> 4030         self._get_axis_number(axis)
#    4031
# ...

# %%
flights.groupby('AIRLINE')['ARR_DELAY'].agg(check_max)
# Out:
# AIRLINE
# AA    True
# AS    True
# B6    True
# DL    True
# EV    True
# F9    True
# HA    True
# MQ    True
# NK    True
# OO    True
# UA    True
# US    True
# VX    True
# WN    True
# Name: ARR_DELAY, dtype: bool

# %%
flights.groupby('AIRLINE')['ARR_DELAY'].agg(check_max,n=1000)
# Out:
# AIRLINE
# AA    False
# AS    False
# B6    False
# DL    False
# EV    False
# F9    False
# HA    False
# MQ    False
# NK    False
# OO    False
# UA     True
# US    False
# VX    False
# WN    False
# Name: ARR_DELAY, dtype: bool

# %% [markdown]
# # TODO
# 1. data/diamonds.csv 를 읽어 DataFrame 생성
# 2. 1에서 생성한 DataFrame의 정보 조회
#     - 배열의 shape조회
#     - 컬럼들의 정보조회
#     - 상/하위 5개 행 조회
# 3. cut별 가격 평균 조회
# 4. clarity별 carat 평균과 표준편차 조회
# 5. cut과 color 별로 가격은 평균을 carat은 최대값을 조회

# %%
#data/diamonds.csv 를 읽어 DataFrame 생성
dia=pd.read_csv('data/diamonds.csv')
dia
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
dia.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
dia.tail()
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64

# %%
dia.info()  # Nan 이하나도 없다./ columns = 10개 , index = 53940개
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
dia.shape
# Out:
# (53940, 10)

# %%
#cut별 가격 평균 조회
dia.groupby('cut')['price'].mean()
# Out:
# cut
# Fair         4358.757764
# Good         3928.864452
# Ideal        3457.541970
# Premium      4584.257704
# Very Good    3981.759891
# Name: price, dtype: float64

# %%
#clarity별 carat 평균과 표준편차 조회
dia.groupby('clarity')[['carat','depth']].agg(['mean','std','median'])
# Out:
#             carat                       depth
#              mean       std median       mean       std median
# clarity
# I1       1.283846  0.632436   1.12  62.734278  2.831829   62.2
# IF       0.505123  0.313433   0.35  61.510615  1.041315   61.7
# SI1      0.850482  0.449652   0.76  61.853042  1.478864   62.0
# SI2      1.077648  0.516653   1.01  61.772167  1.669772   61.9
# VS1      0.727158  0.423529   0.57  61.667458  1.297976   61.8
# VS2      0.763935  0.446292   0.63  61.724417  1.358484   61.8
# VVS1     0.503321  0.299557   0.39  61.624651  1.076419   61.7
# VVS2     0.596202  0.359697   0.44  61.663778  1.166072   61.8

# %%
dia['cut'].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
# cut과 color 별로 가격은 평균을 carat은 최대값을 조회
dia.groupby(['cut','color']).agg({'price':'mean','carat':'max'})
# Out:
#                        price  carat
# cut       color
# Fair      D      4291.061350   3.40
#           E      3682.312500   2.04
#           F      3827.003205   2.58
#           G      4239.254777   2.60
#           H      5135.683168   4.13
#           I      4685.445714   3.02
#           J      4975.655462   5.01
# Good      D      3405.382175   2.04
#           E      3423.644159   3.00
#           F      3495.750275   2.67
#           G      4123.482204   2.80
#           H      4276.254986   3.01
#           I      5078.532567   3.01
#           J      4574.172638   3.00
# Ideal     D      2629.094566   2.75
#           E      2597.550090   2.28
#           F      3374.939362   2.45
#           G      3720.706388   2.54
#           H      3889.334831   3.50
#           I      4451.970377   3.22
#           J      4918.186384   3.01
# Premium   D      3631.292576   2.57
#           E      3538.914420   3.05
#           F      4324.890176   3.01
# ...

# %%
print(dia['cut'].unique())
print(dia['cut'].nunique())
# Out:
# ['Ideal' 'Premium' 'Good' 'Very Good' 'Fair']
# 5

# %%
dia['cut'].value_counts()
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
dia['color'].value_counts()
# Out:
# G    11292
# E     9797
# F     9542
# H     8304
# D     6775
# I     5422
# J     2808
# Name: color, dtype: int64

# %%
dia.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
dia['price'].median()
# Out:
# 2401.0

# %%
dia.describe(include='object')
# Out:
#           cut  color clarity
# count   53940  53940   53940
# unique      5      7       8
# top     Ideal      G     SI1
# freq    21551  11292   13065
